# %% [markdown]
# <a href="https://colab.research.google.com/github/iqbalkap/PruningDistillation/blob/main/Result_Distiller_Student_BiLSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Knowledge Distillation**

# %%
import tensorflow as tf
import os
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.callbacks import ModelCheckpoint
import pandas as pd
import tensorflow
import time
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.layers import (
    LSTM,
    Dense,
    Flatten,
    Dropout,
    BatchNormalization,
    Bidirectional
    )


train = pd.read_csv('/content/drive/MyDrive/Dataset VAE/uncalibrated/train_final_u/train_22_u.csv')
test = pd.read_csv('/content/drive/MyDrive/Dataset VAE/uncalibrated/valid_final_u/valid_22_u.csv')


#del variabel yang tidak dipakai
train = train.drop(['Timestamp', 'Cycle', 'Active Button'], axis=1)
test = test.drop(['Timestamp', 'Cycle', 'Active Button'], axis=1)

print('Input train shape :', train.shape)
print('Input test shape :', test.shape)
# Out:
# Input train shape : (91000, 10)
# Input test shape : (41600, 10)

# %%
# Prepare the train and test dataset.

n_ts = 100 #bebas
n_outputs = 4
n_features = 10

x_train = (train.values[:,0:10])
xt = int(x_train.shape[0]/n_ts) #ubah ke 3D
print('x_train_samples =',xt)
x_train = x_train.reshape((xt, n_ts, 10))
x_train = x_train.astype('float32')
y_train = pd.read_csv('/content/drive/MyDrive/Dataset VAE/hasil_labeling_train_u.csv') #label train
y_train = y_train.astype('float32')

x_test = (test.values[:,0:10])
xs = int(x_test.shape[0]/n_ts)
print('x_test_samples =',xs)
x_test = x_test.reshape((xs,n_ts,10))
x_test = x_test.astype('float32')
y_test = pd.read_csv('/content/drive/MyDrive/Dataset VAE/hasil_labeling_valid_u.csv') #label test
y_test = y_test.astype('float32')

######################
y_train = y_train - 1
y_test = y_test - 1

print('Shape final')
x_train.shape,y_train.shape, x_test.shape, y_test.shape
# Out:
# x_train_samples = 910
# x_test_samples = 416
# Shape final
# ((910, 100, 10), (910, 1), (416, 100, 10), (416, 1))

# %%
# Create the teacher's model
teacher = keras.Sequential(
    [
        keras.Input(shape=(n_ts,n_features)),
        layers.Bidirectional(LSTM(100, activation='tanh')),
        layers.Dropout(0.5),
        layers.Dense(100, activation='relu'),
        layers.Dense(n_outputs, activation='softmax'),
    ],

    name="teacher",
)
teacher.summary()
# Out:
# Model: "teacher"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 200)              88800
#  l)
#
#  dropout (Dropout)           (None, 200)               0
#
#  dense (Dense)               (None, 100)               20100
#
#  dense_1 (Dense)             (None, 4)                 404
#
# =================================================================
# Total params: 109,304
# Trainable params: 109,304
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Create the student's model
student = keras.Sequential(
    [
        keras.Input(shape=(n_ts,n_features)),
        layers.Bidirectional(LSTM(47, activation='tanh')),
        layers.Dropout(0.5),
        layers.Dense(n_outputs),
    ],
    name="student",
)
student.summary()
# Out:
# Model: "student"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (None, 94)               21808
#  nal)
#
#  dropout_1 (Dropout)         (None, 94)                0
#
#  dense_2 (Dense)             (None, 4)                 380
#
# =================================================================
# Total params: 22,188
# Trainable params: 22,188
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Clone student for later comparison
student_scratch = keras.models.clone_model(student)

# %%
start_time = time.perf_counter()

# Train teacher as usual
teacher.compile(loss=tensorflow.keras.losses.sparse_categorical_crossentropy,
              optimizer=tensorflow.keras.optimizers.Adam(),
              metrics=[keras.metrics.SparseCategoricalAccuracy()])

#checkpoint dan save weight untuk teacher
filepath="weights.teacher.hdf5"
checkpoint_teacher = ModelCheckpoint(filepath, monitor='val_sparse_categorical_accuracy', verbose=1, save_best_only=True, mode='max')
#es_teacher = EarlyStopping(monitor='val_sparse_categorical_accuracy', patience=10)
callbacks_teacher_list = [checkpoint_teacher]



#Run teacher RUN!!!
#Fit the model
history = teacher.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=300, batch_size=64, callbacks=callbacks_teacher_list, verbose=2)

print (time.perf_counter() - start_time, "seconds")
# Out:
# Epoch 1/300
#
# Epoch 1: val_sparse_categorical_accuracy improved from -inf to 0.91346, saving model to weights.teacher.hdf5
# 15/15 - 6s - loss: 1.0953 - sparse_categorical_accuracy: 0.5527 - val_loss: 0.6531 - val_sparse_categorical_accuracy: 0.9135 - 6s/epoch - 412ms/step
# Epoch 2/300
#
# Epoch 2: val_sparse_categorical_accuracy improved from 0.91346 to 0.98317, saving model to weights.teacher.hdf5
# 15/15 - 0s - loss: 0.5682 - sparse_categorical_accuracy: 0.8769 - val_loss: 0.2604 - val_sparse_categorical_accuracy: 0.9832 - 282ms/epoch - 19ms/step
# Epoch 3/300
#
# Epoch 3: val_sparse_categorical_accuracy improved from 0.98317 to 0.98798, saving model to weights.teacher.hdf5
# 15/15 - 0s - loss: 0.2906 - sparse_categorical_accuracy: 0.9505 - val_loss: 0.1186 - val_sparse_categorical_accuracy: 0.9880 - 261ms/epoch - 17ms/step
# Epoch 4/300
#
# Epoch 4: val_sparse_categorical_accuracy did not improve from 0.98798
# 15/15 - 0s - loss: 0.1835 - sparse_categorical_accuracy: 0.9692 - val_loss: 0.0769 - val_sparse_categorical_accuracy: 0.9880 - 236ms/epoch - 16ms/step
# Epoch 5/300
#
# Epoch 5: val_sparse_categorical_accuracy did not improve from 0.98798
# 15/15 - 0s - loss: 0.1297 - sparse_categorical_accuracy: 0.9692 - val_loss: 0.0646 - val_sparse_categorical_accuracy: 0.9880 - 239ms/epoch - 16ms/step
# Epoch 6/300
#
# Epoch 6: val_sparse_categorical_accuracy did not improve from 0.98798
# 15/15 - 0s - loss: 0.1107 - sparse_categorical_accuracy: 0.9780 - val_loss: 0.0650 - val_sparse_categorical_accuracy: 0.9880 - 238ms/epoch - 16ms/step
# Epoch 7/300
#
# Epoch 7: val_sparse_categorical_accuracy did not improve from 0.98798
# 15/15 - 0s - loss: 0.1002 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.0661 - val_sparse_categorical_accuracy: 0.9880 - 246ms/epoch - 16ms/step
# Epoch 8/300
#
# Epoch 8: val_sparse_categorical_accuracy did not improve from 0.98798
# 15/15 - 0s - loss: 0.0779 - sparse_categorical_accuracy: 0.9791 - val_loss: 0.0587 - val_sparse_categorical_accuracy: 0.9856 - 233ms/epoch - 16ms/step
# Epoch 9/300
#
# Epoch 9: val_sparse_categorical_accuracy did not improve from 0.98798
# 15/15 - 0s - loss: 0.0746 - sparse_categorical_accuracy: 0.9835 - val_loss: 0.0578 - val_sparse_categorical_accuracy: 0.9856 - 239ms/epoch - 16ms/step
# Epoch 10/300
#
# Epoch 10: val_sparse_categorical_accuracy did not improve from 0.98798
# 15/15 - 0s - loss: 0.0838 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.0604 - val_sparse_categorical_accuracy: 0.9880 - 252ms/epoch - 17ms/step
# Epoch 11/300
#
# Epoch 11: val_sparse_categorical_accuracy did not improve from 0.98798
# 15/15 - 0s - loss: 0.0752 - sparse_categorical_accuracy: 0.9846 - val_loss: 0.0600 - val_sparse_categorical_accuracy: 0.9880 - 234ms/epoch - 16ms/step
# Epoch 12/300
#
# Epoch 12: val_sparse_categorical_accuracy did not improve from 0.98798
# 15/15 - 0s - loss: 0.0723 - sparse_categorical_accuracy: 0.9846 - val_loss: 0.0642 - val_sparse_categorical_accuracy: 0.9856 - 234ms/epoch - 16ms/step
# Epoch 13/300
#
# Epoch 13: val_sparse_categorical_accuracy did not improve from 0.98798
# 15/15 - 0s - loss: 0.0632 - sparse_categorical_accuracy: 0.9868 - val_loss: 0.0628 - val_sparse_categorical_accuracy: 0.9856 - 259ms/epoch - 17ms/step
# Epoch 14/300
#
# Epoch 14: val_sparse_categorical_accuracy did not improve from 0.98798
# 15/15 - 0s - loss: 0.0879 - sparse_categorical_accuracy: 0.9824 - val_loss: 0.0537 - val_sparse_categorical_accuracy: 0.9856 - 272ms/epoch - 18ms/step
# Epoch 15/300
#
# Epoch 15: val_sparse_categorical_accuracy did not improve from 0.98798
# 15/15 - 0s - loss: 0.0801 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.0639 - val_sparse_categorical_accuracy: 0.9856 - 240ms/epoch - 16ms/step
# Epoch 16/300
#
# Epoch 16: val_sparse_categorical_accuracy did not improve from 0.98798
# 15/15 - 0s - loss: 0.0825 - sparse_categorical_accuracy: 0.9813 - val_loss: 0.0706 - val_sparse_categorical_accuracy: 0.9856 - 330ms/epoch - 22ms/step
# Epoch 17/300
#
# Epoch 17: val_sparse_categorical_accuracy did not improve from 0.98798
# 15/15 - 0s - loss: 0.0819 - sparse_categorical_accuracy: 0.9791 - val_loss: 0.0697 - val_sparse_categorical_accuracy: 0.9880 - 350ms/epoch - 23ms/step
# Epoch 18/300
#
# Epoch 18: val_sparse_categorical_accuracy did not improve from 0.98798
# 15/15 - 0s - loss: 0.0772 - sparse_categorical_accuracy: 0.9769 - val_loss: 0.0726 - val_sparse_categorical_accuracy: 0.9880 - 345ms/epoch - 23ms/step
# Epoch 19/300
#
# Epoch 19: val_sparse_categorical_accuracy did not improve from 0.98798
# 15/15 - 0s - loss: 0.0881 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0743 - val_sparse_categorical_accuracy: 0.9880 - 335ms/epoch - 22ms/step
# Epoch 20/300
#
# Epoch 20: val_sparse_categorical_accuracy did not improve from 0.98798
# 15/15 - 0s - loss: 0.0752 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.0708 - val_sparse_categorical_accuracy: 0.9880 - 342ms/epoch - 23ms/step
# Epoch 21/300
#
# Epoch 21: val_sparse_categorical_accuracy did not improve from 0.98798
# 15/15 - 0s - loss: 0.0602 - sparse_categorical_accuracy: 0.9824 - val_loss: 0.0744 - val_sparse_categorical_accuracy: 0.9880 - 341ms/epoch - 23ms/step
# Epoch 22/300
#
# Epoch 22: val_sparse_categorical_accuracy did not improve from 0.98798
# 15/15 - 0s - loss: 0.0483 - sparse_categorical_accuracy: 0.9857 - val_loss: 0.0680 - val_sparse_categorical_accuracy: 0.9856 - 323ms/epoch - 22ms/step
# Epoch 23/300
#
# Epoch 23: val_sparse_categorical_accuracy did not improve from 0.98798
# 15/15 - 0s - loss: 0.0699 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.0672 - val_sparse_categorical_accuracy: 0.9880 - 334ms/epoch - 22ms/step
# Epoch 24/300
#
# Epoch 24: val_sparse_categorical_accuracy did not improve from 0.98798
# 15/15 - 0s - loss: 0.0808 - sparse_categorical_accuracy: 0.9769 - val_loss: 0.0662 - val_sparse_categorical_accuracy: 0.9880 - 334ms/epoch - 22ms/step
# Epoch 25/300
#
# Epoch 25: val_sparse_categorical_accuracy did not improve from 0.98798
# 15/15 - 0s - loss: 0.0627 - sparse_categorical_accuracy: 0.9857 - val_loss: 0.0629 - val_sparse_categorical_accuracy: 0.9880 - 330ms/epoch - 22ms/step
# Epoch 26/300
#
# Epoch 26: val_sparse_categorical_accuracy improved from 0.98798 to 0.99038, saving model to weights.teacher.hdf5
# 15/15 - 0s - loss: 0.0636 - sparse_categorical_accuracy: 0.9824 - val_loss: 0.0640 - val_sparse_categorical_accuracy: 0.9904 - 378ms/epoch - 25ms/step
# Epoch 27/300
#
# Epoch 27: val_sparse_categorical_accuracy did not improve from 0.99038
# 15/15 - 0s - loss: 0.0621 - sparse_categorical_accuracy: 0.9835 - val_loss: 0.0633 - val_sparse_categorical_accuracy: 0.9856 - 257ms/epoch - 17ms/step
# Epoch 28/300
#
# Epoch 28: val_sparse_categorical_accuracy did not improve from 0.99038
# 15/15 - 0s - loss: 0.0722 - sparse_categorical_accuracy: 0.9813 - val_loss: 0.0624 - val_sparse_categorical_accuracy: 0.9904 - 240ms/epoch - 16ms/step
# Epoch 29/300
#
# Epoch 29: val_sparse_categorical_accuracy did not improve from 0.99038
# 15/15 - 0s - loss: 0.0658 - sparse_categorical_accuracy: 0.9791 - val_loss: 0.0692 - val_sparse_categorical_accuracy: 0.9904 - 253ms/epoch - 17ms/step
# Epoch 30/300
#
# Epoch 30: val_sparse_categorical_accuracy did not improve from 0.99038
# 15/15 - 0s - loss: 0.0625 - sparse_categorical_accuracy: 0.9846 - val_loss: 0.0593 - val_sparse_categorical_accuracy: 0.9904 - 233ms/epoch - 16ms/step
# Epoch 31/300
#
# Epoch 31: val_sparse_categorical_accuracy did not improve from 0.99038
# 15/15 - 0s - loss: 0.0543 - sparse_categorical_accuracy: 0.9857 - val_loss: 0.0631 - val_sparse_categorical_accuracy: 0.9904 - 250ms/epoch - 17ms/step
# Epoch 32/300
#
# Epoch 32: val_sparse_categorical_accuracy did not improve from 0.99038
# 15/15 - 0s - loss: 0.0626 - sparse_categorical_accuracy: 0.9813 - val_loss: 0.0646 - val_sparse_categorical_accuracy: 0.9880 - 238ms/epoch - 16ms/step
# Epoch 33/300
#
# Epoch 33: val_sparse_categorical_accuracy did not improve from 0.99038
# 15/15 - 0s - loss: 0.0688 - sparse_categorical_accuracy: 0.9824 - val_loss: 0.0737 - val_sparse_categorical_accuracy: 0.9904 - 246ms/epoch - 16ms/step
# Epoch 34/300
#
# Epoch 34: val_sparse_categorical_accuracy did not improve from 0.99038
# 15/15 - 0s - loss: 0.0725 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.0763 - val_sparse_categorical_accuracy: 0.9904 - 256ms/epoch - 17ms/step
# Epoch 35/300
#
# Epoch 35: val_sparse_categorical_accuracy did not improve from 0.99038
# 15/15 - 0s - loss: 0.0777 - sparse_categorical_accuracy: 0.9769 - val_loss: 0.0752 - val_sparse_categorical_accuracy: 0.9904 - 263ms/epoch - 18ms/step
# Epoch 36/300
#
# Epoch 36: val_sparse_categorical_accuracy did not improve from 0.99038
# 15/15 - 0s - loss: 0.0962 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0731 - val_sparse_categorical_accuracy: 0.9880 - 242ms/epoch - 16ms/step
# Epoch 37/300
#
# Epoch 37: val_sparse_categorical_accuracy did not improve from 0.99038
# 15/15 - 0s - loss: 0.1092 - sparse_categorical_accuracy: 0.9692 - val_loss: 0.0802 - val_sparse_categorical_accuracy: 0.9904 - 237ms/epoch - 16ms/step
# Epoch 38/300
#
# Epoch 38: val_sparse_categorical_accuracy did not improve from 0.99038
# 15/15 - 0s - loss: 0.0789 - sparse_categorical_accuracy: 0.9791 - val_loss: 0.0734 - val_sparse_categorical_accuracy: 0.9904 - 229ms/epoch - 15ms/step
# Epoch 39/300
#
# Epoch 39: val_sparse_categorical_accuracy did not improve from 0.99038
# 15/15 - 0s - loss: 0.0730 - sparse_categorical_accuracy: 0.9857 - val_loss: 0.0805 - val_sparse_categorical_accuracy: 0.9880 - 256ms/epoch - 17ms/step
# Epoch 40/300
#
# Epoch 40: val_sparse_categorical_accuracy did not improve from 0.99038
# 15/15 - 0s - loss: 0.1043 - sparse_categorical_accuracy: 0.9648 - val_loss: 0.0711 - val_sparse_categorical_accuracy: 0.9880 - 249ms/epoch - 17ms/step
# Epoch 41/300
#
# Epoch 41: val_sparse_categorical_accuracy did not improve from 0.99038
# 15/15 - 0s - loss: 0.1226 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.0762 - val_sparse_categorical_accuracy: 0.9880 - 239ms/epoch - 16ms/step
# Epoch 42/300
#
# Epoch 42: val_sparse_categorical_accuracy did not improve from 0.99038
# 15/15 - 0s - loss: 0.1504 - sparse_categorical_accuracy: 0.9527 - val_loss: 0.0766 - val_sparse_categorical_accuracy: 0.9904 - 242ms/epoch - 16ms/step
# Epoch 43/300
#
# Epoch 43: val_sparse_categorical_accuracy did not improve from 0.99038
# 15/15 - 0s - loss: 0.1865 - sparse_categorical_accuracy: 0.9308 - val_loss: 0.0642 - val_sparse_categorical_accuracy: 0.9904 - 246ms/epoch - 16ms/step
# Epoch 44/300
#
# Epoch 44: val_sparse_categorical_accuracy did not improve from 0.99038
# 15/15 - 0s - loss: 0.1586 - sparse_categorical_accuracy: 0.9505 - val_loss: 0.0642 - val_sparse_categorical_accuracy: 0.9880 - 239ms/epoch - 16ms/step
# Epoch 45/300
#
# Epoch 45: val_sparse_categorical_accuracy improved from 0.99038 to 0.99279, saving model to weights.teacher.hdf5
# 15/15 - 0s - loss: 0.1618 - sparse_categorical_accuracy: 0.9407 - val_loss: 0.0558 - val_sparse_categorical_accuracy: 0.9928 - 266ms/epoch - 18ms/step
# Epoch 46/300
#
# Epoch 46: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1565 - sparse_categorical_accuracy: 0.9560 - val_loss: 0.0776 - val_sparse_categorical_accuracy: 0.9904 - 234ms/epoch - 16ms/step
# Epoch 47/300
#
# Epoch 47: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1732 - sparse_categorical_accuracy: 0.9385 - val_loss: 0.0690 - val_sparse_categorical_accuracy: 0.9880 - 241ms/epoch - 16ms/step
# Epoch 48/300
#
# Epoch 48: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1310 - sparse_categorical_accuracy: 0.9615 - val_loss: 0.0682 - val_sparse_categorical_accuracy: 0.9904 - 228ms/epoch - 15ms/step
# Epoch 49/300
#
# Epoch 49: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1024 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0601 - val_sparse_categorical_accuracy: 0.9880 - 259ms/epoch - 17ms/step
# Epoch 50/300
#
# Epoch 50: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1198 - sparse_categorical_accuracy: 0.9615 - val_loss: 0.0702 - val_sparse_categorical_accuracy: 0.9880 - 233ms/epoch - 16ms/step
# Epoch 51/300
#
# Epoch 51: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1012 - sparse_categorical_accuracy: 0.9703 - val_loss: 0.0726 - val_sparse_categorical_accuracy: 0.9880 - 263ms/epoch - 18ms/step
# Epoch 52/300
#
# Epoch 52: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1397 - sparse_categorical_accuracy: 0.9516 - val_loss: 0.0648 - val_sparse_categorical_accuracy: 0.9904 - 257ms/epoch - 17ms/step
# Epoch 53/300
#
# Epoch 53: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1434 - sparse_categorical_accuracy: 0.9473 - val_loss: 0.0756 - val_sparse_categorical_accuracy: 0.9856 - 248ms/epoch - 17ms/step
# Epoch 54/300
#
# Epoch 54: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1239 - sparse_categorical_accuracy: 0.9604 - val_loss: 0.0760 - val_sparse_categorical_accuracy: 0.9904 - 240ms/epoch - 16ms/step
# Epoch 55/300
#
# Epoch 55: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1236 - sparse_categorical_accuracy: 0.9648 - val_loss: 0.0774 - val_sparse_categorical_accuracy: 0.9904 - 243ms/epoch - 16ms/step
# Epoch 56/300
#
# Epoch 56: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1257 - sparse_categorical_accuracy: 0.9615 - val_loss: 0.0749 - val_sparse_categorical_accuracy: 0.9904 - 237ms/epoch - 16ms/step
# Epoch 57/300
#
# Epoch 57: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1063 - sparse_categorical_accuracy: 0.9692 - val_loss: 0.0837 - val_sparse_categorical_accuracy: 0.9856 - 243ms/epoch - 16ms/step
# Epoch 58/300
#
# Epoch 58: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0892 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0709 - val_sparse_categorical_accuracy: 0.9928 - 246ms/epoch - 16ms/step
# Epoch 59/300
#
# Epoch 59: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0820 - sparse_categorical_accuracy: 0.9791 - val_loss: 0.0730 - val_sparse_categorical_accuracy: 0.9928 - 247ms/epoch - 16ms/step
# Epoch 60/300
#
# Epoch 60: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0897 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.0788 - val_sparse_categorical_accuracy: 0.9856 - 234ms/epoch - 16ms/step
# Epoch 61/300
#
# Epoch 61: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0945 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.0768 - val_sparse_categorical_accuracy: 0.9904 - 239ms/epoch - 16ms/step
# Epoch 62/300
#
# Epoch 62: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1184 - sparse_categorical_accuracy: 0.9604 - val_loss: 0.0772 - val_sparse_categorical_accuracy: 0.9856 - 228ms/epoch - 15ms/step
# Epoch 63/300
#
# Epoch 63: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1876 - sparse_categorical_accuracy: 0.9341 - val_loss: 0.0723 - val_sparse_categorical_accuracy: 0.9904 - 249ms/epoch - 17ms/step
# Epoch 64/300
#
# Epoch 64: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1462 - sparse_categorical_accuracy: 0.9571 - val_loss: 0.0731 - val_sparse_categorical_accuracy: 0.9880 - 239ms/epoch - 16ms/step
# Epoch 65/300
#
# Epoch 65: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1576 - sparse_categorical_accuracy: 0.9462 - val_loss: 0.0714 - val_sparse_categorical_accuracy: 0.9928 - 239ms/epoch - 16ms/step
# Epoch 66/300
#
# Epoch 66: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1121 - sparse_categorical_accuracy: 0.9637 - val_loss: 0.0817 - val_sparse_categorical_accuracy: 0.9880 - 229ms/epoch - 15ms/step
# Epoch 67/300
#
# Epoch 67: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0996 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.0930 - val_sparse_categorical_accuracy: 0.9880 - 240ms/epoch - 16ms/step
# Epoch 68/300
#
# Epoch 68: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0840 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0862 - val_sparse_categorical_accuracy: 0.9856 - 249ms/epoch - 17ms/step
# Epoch 69/300
#
# Epoch 69: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1008 - sparse_categorical_accuracy: 0.9681 - val_loss: 0.0861 - val_sparse_categorical_accuracy: 0.9856 - 237ms/epoch - 16ms/step
# Epoch 70/300
#
# Epoch 70: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0916 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.0824 - val_sparse_categorical_accuracy: 0.9856 - 242ms/epoch - 16ms/step
# Epoch 71/300
#
# Epoch 71: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0895 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.0763 - val_sparse_categorical_accuracy: 0.9880 - 241ms/epoch - 16ms/step
# Epoch 72/300
#
# Epoch 72: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0983 - sparse_categorical_accuracy: 0.9692 - val_loss: 0.0762 - val_sparse_categorical_accuracy: 0.9880 - 253ms/epoch - 17ms/step
# Epoch 73/300
#
# Epoch 73: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1051 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0789 - val_sparse_categorical_accuracy: 0.9880 - 238ms/epoch - 16ms/step
# Epoch 74/300
#
# Epoch 74: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1039 - sparse_categorical_accuracy: 0.9648 - val_loss: 0.0815 - val_sparse_categorical_accuracy: 0.9856 - 244ms/epoch - 16ms/step
# Epoch 75/300
#
# Epoch 75: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1041 - sparse_categorical_accuracy: 0.9626 - val_loss: 0.0754 - val_sparse_categorical_accuracy: 0.9880 - 234ms/epoch - 16ms/step
# Epoch 76/300
#
# Epoch 76: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1067 - sparse_categorical_accuracy: 0.9593 - val_loss: 0.0717 - val_sparse_categorical_accuracy: 0.9904 - 244ms/epoch - 16ms/step
# Epoch 77/300
#
# Epoch 77: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0880 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0729 - val_sparse_categorical_accuracy: 0.9904 - 236ms/epoch - 16ms/step
# Epoch 78/300
#
# Epoch 78: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1340 - sparse_categorical_accuracy: 0.9571 - val_loss: 0.0822 - val_sparse_categorical_accuracy: 0.9880 - 241ms/epoch - 16ms/step
# Epoch 79/300
#
# Epoch 79: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0925 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0764 - val_sparse_categorical_accuracy: 0.9880 - 240ms/epoch - 16ms/step
# Epoch 80/300
#
# Epoch 80: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0950 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0818 - val_sparse_categorical_accuracy: 0.9832 - 236ms/epoch - 16ms/step
# Epoch 81/300
#
# Epoch 81: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0885 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0820 - val_sparse_categorical_accuracy: 0.9832 - 261ms/epoch - 17ms/step
# Epoch 82/300
#
# Epoch 82: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0708 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0743 - val_sparse_categorical_accuracy: 0.9856 - 238ms/epoch - 16ms/step
# Epoch 83/300
#
# Epoch 83: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1002 - sparse_categorical_accuracy: 0.9692 - val_loss: 0.0825 - val_sparse_categorical_accuracy: 0.9880 - 238ms/epoch - 16ms/step
# Epoch 84/300
#
# Epoch 84: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1159 - sparse_categorical_accuracy: 0.9615 - val_loss: 0.0767 - val_sparse_categorical_accuracy: 0.9880 - 248ms/epoch - 17ms/step
# Epoch 85/300
#
# Epoch 85: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0985 - sparse_categorical_accuracy: 0.9615 - val_loss: 0.0808 - val_sparse_categorical_accuracy: 0.9904 - 237ms/epoch - 16ms/step
# Epoch 86/300
#
# Epoch 86: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0794 - sparse_categorical_accuracy: 0.9703 - val_loss: 0.0756 - val_sparse_categorical_accuracy: 0.9880 - 242ms/epoch - 16ms/step
# Epoch 87/300
#
# Epoch 87: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0913 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0780 - val_sparse_categorical_accuracy: 0.9856 - 231ms/epoch - 15ms/step
# Epoch 88/300
#
# Epoch 88: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0752 - sparse_categorical_accuracy: 0.9780 - val_loss: 0.0837 - val_sparse_categorical_accuracy: 0.9880 - 251ms/epoch - 17ms/step
# Epoch 89/300
#
# Epoch 89: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0772 - sparse_categorical_accuracy: 0.9824 - val_loss: 0.0873 - val_sparse_categorical_accuracy: 0.9856 - 236ms/epoch - 16ms/step
# Epoch 90/300
#
# Epoch 90: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0865 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0820 - val_sparse_categorical_accuracy: 0.9856 - 247ms/epoch - 16ms/step
# Epoch 91/300
#
# Epoch 91: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0730 - sparse_categorical_accuracy: 0.9791 - val_loss: 0.0984 - val_sparse_categorical_accuracy: 0.9856 - 243ms/epoch - 16ms/step
# Epoch 92/300
#
# Epoch 92: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0891 - sparse_categorical_accuracy: 0.9692 - val_loss: 0.0870 - val_sparse_categorical_accuracy: 0.9880 - 243ms/epoch - 16ms/step
# Epoch 93/300
#
# Epoch 93: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0881 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0865 - val_sparse_categorical_accuracy: 0.9880 - 253ms/epoch - 17ms/step
# Epoch 94/300
#
# Epoch 94: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0757 - sparse_categorical_accuracy: 0.9846 - val_loss: 0.0982 - val_sparse_categorical_accuracy: 0.9880 - 253ms/epoch - 17ms/step
# Epoch 95/300
#
# Epoch 95: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0760 - sparse_categorical_accuracy: 0.9780 - val_loss: 0.0884 - val_sparse_categorical_accuracy: 0.9856 - 233ms/epoch - 16ms/step
# Epoch 96/300
#
# Epoch 96: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0860 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0927 - val_sparse_categorical_accuracy: 0.9880 - 239ms/epoch - 16ms/step
# Epoch 97/300
#
# Epoch 97: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0761 - sparse_categorical_accuracy: 0.9769 - val_loss: 0.0857 - val_sparse_categorical_accuracy: 0.9904 - 234ms/epoch - 16ms/step
# Epoch 98/300
#
# Epoch 98: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0983 - sparse_categorical_accuracy: 0.9692 - val_loss: 0.0863 - val_sparse_categorical_accuracy: 0.9904 - 252ms/epoch - 17ms/step
# Epoch 99/300
#
# Epoch 99: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0977 - sparse_categorical_accuracy: 0.9692 - val_loss: 0.0900 - val_sparse_categorical_accuracy: 0.9880 - 242ms/epoch - 16ms/step
# Epoch 100/300
#
# Epoch 100: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1074 - sparse_categorical_accuracy: 0.9692 - val_loss: 0.0900 - val_sparse_categorical_accuracy: 0.9904 - 247ms/epoch - 16ms/step
# Epoch 101/300
#
# Epoch 101: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0842 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0879 - val_sparse_categorical_accuracy: 0.9880 - 252ms/epoch - 17ms/step
# Epoch 102/300
#
# Epoch 102: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0987 - sparse_categorical_accuracy: 0.9692 - val_loss: 0.0845 - val_sparse_categorical_accuracy: 0.9904 - 243ms/epoch - 16ms/step
# Epoch 103/300
#
# Epoch 103: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1043 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.0927 - val_sparse_categorical_accuracy: 0.9856 - 235ms/epoch - 16ms/step
# Epoch 104/300
#
# Epoch 104: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0864 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.0902 - val_sparse_categorical_accuracy: 0.9880 - 258ms/epoch - 17ms/step
# Epoch 105/300
#
# Epoch 105: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0846 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0926 - val_sparse_categorical_accuracy: 0.9880 - 233ms/epoch - 16ms/step
# Epoch 106/300
#
# Epoch 106: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0740 - sparse_categorical_accuracy: 0.9791 - val_loss: 0.0941 - val_sparse_categorical_accuracy: 0.9880 - 237ms/epoch - 16ms/step
# Epoch 107/300
#
# Epoch 107: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0779 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.1049 - val_sparse_categorical_accuracy: 0.9856 - 233ms/epoch - 16ms/step
# Epoch 108/300
#
# Epoch 108: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0711 - sparse_categorical_accuracy: 0.9780 - val_loss: 0.0954 - val_sparse_categorical_accuracy: 0.9856 - 234ms/epoch - 16ms/step
# Epoch 109/300
#
# Epoch 109: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0911 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0844 - val_sparse_categorical_accuracy: 0.9880 - 254ms/epoch - 17ms/step
# Epoch 110/300
#
# Epoch 110: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0811 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0953 - val_sparse_categorical_accuracy: 0.9856 - 264ms/epoch - 18ms/step
# Epoch 111/300
#
# Epoch 111: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0718 - sparse_categorical_accuracy: 0.9824 - val_loss: 0.0982 - val_sparse_categorical_accuracy: 0.9856 - 246ms/epoch - 16ms/step
# Epoch 112/300
#
# Epoch 112: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0642 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.0903 - val_sparse_categorical_accuracy: 0.9880 - 242ms/epoch - 16ms/step
# Epoch 113/300
#
# Epoch 113: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1095 - sparse_categorical_accuracy: 0.9615 - val_loss: 0.0846 - val_sparse_categorical_accuracy: 0.9856 - 246ms/epoch - 16ms/step
# Epoch 114/300
#
# Epoch 114: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0649 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.0921 - val_sparse_categorical_accuracy: 0.9856 - 241ms/epoch - 16ms/step
# Epoch 115/300
#
# Epoch 115: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0905 - sparse_categorical_accuracy: 0.9703 - val_loss: 0.0916 - val_sparse_categorical_accuracy: 0.9880 - 242ms/epoch - 16ms/step
# Epoch 116/300
#
# Epoch 116: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0821 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.0853 - val_sparse_categorical_accuracy: 0.9880 - 241ms/epoch - 16ms/step
# Epoch 117/300
#
# Epoch 117: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0900 - sparse_categorical_accuracy: 0.9791 - val_loss: 0.0825 - val_sparse_categorical_accuracy: 0.9904 - 243ms/epoch - 16ms/step
# Epoch 118/300
#
# Epoch 118: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0747 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.0815 - val_sparse_categorical_accuracy: 0.9904 - 251ms/epoch - 17ms/step
# Epoch 119/300
#
# Epoch 119: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0840 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.0824 - val_sparse_categorical_accuracy: 0.9904 - 231ms/epoch - 15ms/step
# Epoch 120/300
#
# Epoch 120: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0986 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.0862 - val_sparse_categorical_accuracy: 0.9904 - 234ms/epoch - 16ms/step
# Epoch 121/300
#
# Epoch 121: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0911 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0886 - val_sparse_categorical_accuracy: 0.9856 - 241ms/epoch - 16ms/step
# Epoch 122/300
#
# Epoch 122: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1103 - sparse_categorical_accuracy: 0.9648 - val_loss: 0.0942 - val_sparse_categorical_accuracy: 0.9880 - 239ms/epoch - 16ms/step
# Epoch 123/300
#
# Epoch 123: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0871 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0966 - val_sparse_categorical_accuracy: 0.9880 - 240ms/epoch - 16ms/step
# Epoch 124/300
#
# Epoch 124: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0857 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.0864 - val_sparse_categorical_accuracy: 0.9928 - 234ms/epoch - 16ms/step
# Epoch 125/300
#
# Epoch 125: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1021 - sparse_categorical_accuracy: 0.9615 - val_loss: 0.0875 - val_sparse_categorical_accuracy: 0.9928 - 255ms/epoch - 17ms/step
# Epoch 126/300
#
# Epoch 126: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1006 - sparse_categorical_accuracy: 0.9648 - val_loss: 0.0836 - val_sparse_categorical_accuracy: 0.9928 - 237ms/epoch - 16ms/step
# Epoch 127/300
#
# Epoch 127: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1008 - sparse_categorical_accuracy: 0.9703 - val_loss: 0.0906 - val_sparse_categorical_accuracy: 0.9904 - 235ms/epoch - 16ms/step
# Epoch 128/300
#
# Epoch 128: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0922 - sparse_categorical_accuracy: 0.9692 - val_loss: 0.0855 - val_sparse_categorical_accuracy: 0.9928 - 249ms/epoch - 17ms/step
# Epoch 129/300
#
# Epoch 129: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0850 - sparse_categorical_accuracy: 0.9791 - val_loss: 0.0893 - val_sparse_categorical_accuracy: 0.9904 - 253ms/epoch - 17ms/step
# Epoch 130/300
#
# Epoch 130: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0683 - sparse_categorical_accuracy: 0.9791 - val_loss: 0.0873 - val_sparse_categorical_accuracy: 0.9904 - 249ms/epoch - 17ms/step
# Epoch 131/300
#
# Epoch 131: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0787 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0870 - val_sparse_categorical_accuracy: 0.9880 - 238ms/epoch - 16ms/step
# Epoch 132/300
#
# Epoch 132: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0780 - sparse_categorical_accuracy: 0.9780 - val_loss: 0.0921 - val_sparse_categorical_accuracy: 0.9880 - 260ms/epoch - 17ms/step
# Epoch 133/300
#
# Epoch 133: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0914 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.0980 - val_sparse_categorical_accuracy: 0.9880 - 252ms/epoch - 17ms/step
# Epoch 134/300
#
# Epoch 134: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0634 - sparse_categorical_accuracy: 0.9835 - val_loss: 0.0982 - val_sparse_categorical_accuracy: 0.9880 - 239ms/epoch - 16ms/step
# Epoch 135/300
#
# Epoch 135: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0699 - sparse_categorical_accuracy: 0.9813 - val_loss: 0.0953 - val_sparse_categorical_accuracy: 0.9856 - 262ms/epoch - 17ms/step
# Epoch 136/300
#
# Epoch 136: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0815 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0887 - val_sparse_categorical_accuracy: 0.9904 - 234ms/epoch - 16ms/step
# Epoch 137/300
#
# Epoch 137: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0998 - sparse_categorical_accuracy: 0.9681 - val_loss: 0.0922 - val_sparse_categorical_accuracy: 0.9904 - 250ms/epoch - 17ms/step
# Epoch 138/300
#
# Epoch 138: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0587 - sparse_categorical_accuracy: 0.9780 - val_loss: 0.0902 - val_sparse_categorical_accuracy: 0.9904 - 251ms/epoch - 17ms/step
# Epoch 139/300
#
# Epoch 139: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0538 - sparse_categorical_accuracy: 0.9857 - val_loss: 0.0898 - val_sparse_categorical_accuracy: 0.9880 - 247ms/epoch - 16ms/step
# Epoch 140/300
#
# Epoch 140: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0746 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.0884 - val_sparse_categorical_accuracy: 0.9928 - 244ms/epoch - 16ms/step
# Epoch 141/300
#
# Epoch 141: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0868 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0874 - val_sparse_categorical_accuracy: 0.9928 - 256ms/epoch - 17ms/step
# Epoch 142/300
#
# Epoch 142: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0650 - sparse_categorical_accuracy: 0.9791 - val_loss: 0.0933 - val_sparse_categorical_accuracy: 0.9928 - 257ms/epoch - 17ms/step
# Epoch 143/300
#
# Epoch 143: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0870 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0939 - val_sparse_categorical_accuracy: 0.9928 - 237ms/epoch - 16ms/step
# Epoch 144/300
#
# Epoch 144: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0952 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.0983 - val_sparse_categorical_accuracy: 0.9904 - 236ms/epoch - 16ms/step
# Epoch 145/300
#
# Epoch 145: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0807 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.0957 - val_sparse_categorical_accuracy: 0.9904 - 245ms/epoch - 16ms/step
# Epoch 146/300
#
# Epoch 146: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0660 - sparse_categorical_accuracy: 0.9824 - val_loss: 0.0943 - val_sparse_categorical_accuracy: 0.9904 - 243ms/epoch - 16ms/step
# Epoch 147/300
#
# Epoch 147: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0877 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0929 - val_sparse_categorical_accuracy: 0.9904 - 231ms/epoch - 15ms/step
# Epoch 148/300
#
# Epoch 148: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0883 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.1075 - val_sparse_categorical_accuracy: 0.9880 - 240ms/epoch - 16ms/step
# Epoch 149/300
#
# Epoch 149: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1183 - sparse_categorical_accuracy: 0.9637 - val_loss: 0.1001 - val_sparse_categorical_accuracy: 0.9880 - 267ms/epoch - 18ms/step
# Epoch 150/300
#
# Epoch 150: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1271 - sparse_categorical_accuracy: 0.9626 - val_loss: 0.1009 - val_sparse_categorical_accuracy: 0.9880 - 229ms/epoch - 15ms/step
# Epoch 151/300
#
# Epoch 151: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0935 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0879 - val_sparse_categorical_accuracy: 0.9880 - 240ms/epoch - 16ms/step
# Epoch 152/300
#
# Epoch 152: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0944 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.0806 - val_sparse_categorical_accuracy: 0.9928 - 241ms/epoch - 16ms/step
# Epoch 153/300
#
# Epoch 153: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0857 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0745 - val_sparse_categorical_accuracy: 0.9904 - 248ms/epoch - 17ms/step
# Epoch 154/300
#
# Epoch 154: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0946 - sparse_categorical_accuracy: 0.9692 - val_loss: 0.0740 - val_sparse_categorical_accuracy: 0.9928 - 248ms/epoch - 17ms/step
# Epoch 155/300
#
# Epoch 155: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0800 - sparse_categorical_accuracy: 0.9780 - val_loss: 0.0825 - val_sparse_categorical_accuracy: 0.9928 - 234ms/epoch - 16ms/step
# Epoch 156/300
#
# Epoch 156: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0614 - sparse_categorical_accuracy: 0.9824 - val_loss: 0.0777 - val_sparse_categorical_accuracy: 0.9904 - 250ms/epoch - 17ms/step
# Epoch 157/300
#
# Epoch 157: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0851 - sparse_categorical_accuracy: 0.9692 - val_loss: 0.0766 - val_sparse_categorical_accuracy: 0.9904 - 243ms/epoch - 16ms/step
# Epoch 158/300
#
# Epoch 158: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0986 - sparse_categorical_accuracy: 0.9648 - val_loss: 0.0753 - val_sparse_categorical_accuracy: 0.9928 - 251ms/epoch - 17ms/step
# Epoch 159/300
#
# Epoch 159: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0799 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0792 - val_sparse_categorical_accuracy: 0.9928 - 227ms/epoch - 15ms/step
# Epoch 160/300
#
# Epoch 160: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0721 - sparse_categorical_accuracy: 0.9769 - val_loss: 0.0781 - val_sparse_categorical_accuracy: 0.9904 - 243ms/epoch - 16ms/step
# Epoch 161/300
#
# Epoch 161: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0909 - sparse_categorical_accuracy: 0.9681 - val_loss: 0.0838 - val_sparse_categorical_accuracy: 0.9904 - 269ms/epoch - 18ms/step
# Epoch 162/300
#
# Epoch 162: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0822 - sparse_categorical_accuracy: 0.9780 - val_loss: 0.0869 - val_sparse_categorical_accuracy: 0.9880 - 248ms/epoch - 17ms/step
# Epoch 163/300
#
# Epoch 163: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0938 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.1026 - val_sparse_categorical_accuracy: 0.9880 - 233ms/epoch - 16ms/step
# Epoch 164/300
#
# Epoch 164: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1111 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.0878 - val_sparse_categorical_accuracy: 0.9880 - 242ms/epoch - 16ms/step
# Epoch 165/300
#
# Epoch 165: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0792 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.1063 - val_sparse_categorical_accuracy: 0.9880 - 240ms/epoch - 16ms/step
# Epoch 166/300
#
# Epoch 166: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1601 - sparse_categorical_accuracy: 0.9505 - val_loss: 0.0926 - val_sparse_categorical_accuracy: 0.9880 - 253ms/epoch - 17ms/step
# Epoch 167/300
#
# Epoch 167: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1187 - sparse_categorical_accuracy: 0.9527 - val_loss: 0.0925 - val_sparse_categorical_accuracy: 0.9880 - 232ms/epoch - 15ms/step
# Epoch 168/300
#
# Epoch 168: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1268 - sparse_categorical_accuracy: 0.9549 - val_loss: 0.0841 - val_sparse_categorical_accuracy: 0.9904 - 249ms/epoch - 17ms/step
# Epoch 169/300
#
# Epoch 169: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1218 - sparse_categorical_accuracy: 0.9637 - val_loss: 0.0844 - val_sparse_categorical_accuracy: 0.9880 - 243ms/epoch - 16ms/step
# Epoch 170/300
#
# Epoch 170: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0902 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0909 - val_sparse_categorical_accuracy: 0.9880 - 250ms/epoch - 17ms/step
# Epoch 171/300
#
# Epoch 171: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0810 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0854 - val_sparse_categorical_accuracy: 0.9880 - 234ms/epoch - 16ms/step
# Epoch 172/300
#
# Epoch 172: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0875 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0868 - val_sparse_categorical_accuracy: 0.9880 - 244ms/epoch - 16ms/step
# Epoch 173/300
#
# Epoch 173: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0820 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0938 - val_sparse_categorical_accuracy: 0.9880 - 256ms/epoch - 17ms/step
# Epoch 174/300
#
# Epoch 174: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0911 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.0955 - val_sparse_categorical_accuracy: 0.9880 - 246ms/epoch - 16ms/step
# Epoch 175/300
#
# Epoch 175: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1110 - sparse_categorical_accuracy: 0.9648 - val_loss: 0.0930 - val_sparse_categorical_accuracy: 0.9880 - 238ms/epoch - 16ms/step
# Epoch 176/300
#
# Epoch 176: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0735 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0956 - val_sparse_categorical_accuracy: 0.9880 - 247ms/epoch - 16ms/step
# Epoch 177/300
#
# Epoch 177: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1015 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.0970 - val_sparse_categorical_accuracy: 0.9880 - 245ms/epoch - 16ms/step
# Epoch 178/300
#
# Epoch 178: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0774 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0955 - val_sparse_categorical_accuracy: 0.9880 - 252ms/epoch - 17ms/step
# Epoch 179/300
#
# Epoch 179: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0786 - sparse_categorical_accuracy: 0.9703 - val_loss: 0.0879 - val_sparse_categorical_accuracy: 0.9880 - 237ms/epoch - 16ms/step
# Epoch 180/300
#
# Epoch 180: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0760 - sparse_categorical_accuracy: 0.9791 - val_loss: 0.0835 - val_sparse_categorical_accuracy: 0.9904 - 242ms/epoch - 16ms/step
# Epoch 181/300
#
# Epoch 181: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0796 - sparse_categorical_accuracy: 0.9780 - val_loss: 0.0886 - val_sparse_categorical_accuracy: 0.9880 - 236ms/epoch - 16ms/step
# Epoch 182/300
#
# Epoch 182: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0721 - sparse_categorical_accuracy: 0.9769 - val_loss: 0.0911 - val_sparse_categorical_accuracy: 0.9904 - 247ms/epoch - 16ms/step
# Epoch 183/300
#
# Epoch 183: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0720 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.0855 - val_sparse_categorical_accuracy: 0.9904 - 235ms/epoch - 16ms/step
# Epoch 184/300
#
# Epoch 184: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1069 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.0912 - val_sparse_categorical_accuracy: 0.9880 - 227ms/epoch - 15ms/step
# Epoch 185/300
#
# Epoch 185: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0871 - sparse_categorical_accuracy: 0.9780 - val_loss: 0.0795 - val_sparse_categorical_accuracy: 0.9904 - 247ms/epoch - 16ms/step
# Epoch 186/300
#
# Epoch 186: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1047 - sparse_categorical_accuracy: 0.9692 - val_loss: 0.0860 - val_sparse_categorical_accuracy: 0.9904 - 238ms/epoch - 16ms/step
# Epoch 187/300
#
# Epoch 187: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1097 - sparse_categorical_accuracy: 0.9593 - val_loss: 0.0789 - val_sparse_categorical_accuracy: 0.9904 - 233ms/epoch - 16ms/step
# Epoch 188/300
#
# Epoch 188: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1041 - sparse_categorical_accuracy: 0.9648 - val_loss: 0.0761 - val_sparse_categorical_accuracy: 0.9904 - 234ms/epoch - 16ms/step
# Epoch 189/300
#
# Epoch 189: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1111 - sparse_categorical_accuracy: 0.9615 - val_loss: 0.0793 - val_sparse_categorical_accuracy: 0.9904 - 231ms/epoch - 15ms/step
# Epoch 190/300
#
# Epoch 190: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1534 - sparse_categorical_accuracy: 0.9462 - val_loss: 0.0792 - val_sparse_categorical_accuracy: 0.9904 - 240ms/epoch - 16ms/step
# Epoch 191/300
#
# Epoch 191: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1660 - sparse_categorical_accuracy: 0.9560 - val_loss: 0.0770 - val_sparse_categorical_accuracy: 0.9904 - 245ms/epoch - 16ms/step
# Epoch 192/300
#
# Epoch 192: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1351 - sparse_categorical_accuracy: 0.9593 - val_loss: 0.0851 - val_sparse_categorical_accuracy: 0.9904 - 239ms/epoch - 16ms/step
# Epoch 193/300
#
# Epoch 193: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1299 - sparse_categorical_accuracy: 0.9659 - val_loss: 0.0837 - val_sparse_categorical_accuracy: 0.9880 - 232ms/epoch - 15ms/step
# Epoch 194/300
#
# Epoch 194: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1333 - sparse_categorical_accuracy: 0.9582 - val_loss: 0.0833 - val_sparse_categorical_accuracy: 0.9904 - 240ms/epoch - 16ms/step
# Epoch 195/300
#
# Epoch 195: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0998 - sparse_categorical_accuracy: 0.9604 - val_loss: 0.0807 - val_sparse_categorical_accuracy: 0.9904 - 229ms/epoch - 15ms/step
# Epoch 196/300
#
# Epoch 196: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0949 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0832 - val_sparse_categorical_accuracy: 0.9904 - 233ms/epoch - 16ms/step
# Epoch 197/300
#
# Epoch 197: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0685 - sparse_categorical_accuracy: 0.9846 - val_loss: 0.0838 - val_sparse_categorical_accuracy: 0.9904 - 227ms/epoch - 15ms/step
# Epoch 198/300
#
# Epoch 198: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0741 - sparse_categorical_accuracy: 0.9791 - val_loss: 0.0870 - val_sparse_categorical_accuracy: 0.9904 - 227ms/epoch - 15ms/step
# Epoch 199/300
#
# Epoch 199: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0952 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0859 - val_sparse_categorical_accuracy: 0.9904 - 245ms/epoch - 16ms/step
# Epoch 200/300
#
# Epoch 200: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0769 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0903 - val_sparse_categorical_accuracy: 0.9880 - 234ms/epoch - 16ms/step
# Epoch 201/300
#
# Epoch 201: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0829 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0876 - val_sparse_categorical_accuracy: 0.9880 - 234ms/epoch - 16ms/step
# Epoch 202/300
#
# Epoch 202: val_sparse_categorical_accuracy did not improve from 0.99279
# ...
# Epoch 234/300
#
# Epoch 234: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0587 - sparse_categorical_accuracy: 0.9813 - val_loss: 0.0848 - val_sparse_categorical_accuracy: 0.9928 - 244ms/epoch - 16ms/step
# Epoch 235/300
#
# Epoch 235: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0571 - sparse_categorical_accuracy: 0.9857 - val_loss: 0.0869 - val_sparse_categorical_accuracy: 0.9928 - 238ms/epoch - 16ms/step
# Epoch 236/300
#
# Epoch 236: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0542 - sparse_categorical_accuracy: 0.9835 - val_loss: 0.0880 - val_sparse_categorical_accuracy: 0.9928 - 241ms/epoch - 16ms/step
# Epoch 237/300
#
# Epoch 237: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0694 - sparse_categorical_accuracy: 0.9791 - val_loss: 0.0876 - val_sparse_categorical_accuracy: 0.9904 - 241ms/epoch - 16ms/step
# Epoch 238/300
#
# Epoch 238: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0553 - sparse_categorical_accuracy: 0.9824 - val_loss: 0.0862 - val_sparse_categorical_accuracy: 0.9928 - 234ms/epoch - 16ms/step
# Epoch 239/300
#
# Epoch 239: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0637 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.0910 - val_sparse_categorical_accuracy: 0.9904 - 238ms/epoch - 16ms/step
# Epoch 240/300
#
# Epoch 240: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0664 - sparse_categorical_accuracy: 0.9835 - val_loss: 0.0882 - val_sparse_categorical_accuracy: 0.9904 - 244ms/epoch - 16ms/step
# Epoch 241/300
#
# Epoch 241: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0686 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.0814 - val_sparse_categorical_accuracy: 0.9928 - 236ms/epoch - 16ms/step
# Epoch 242/300
#
# Epoch 242: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0518 - sparse_categorical_accuracy: 0.9813 - val_loss: 0.0829 - val_sparse_categorical_accuracy: 0.9904 - 253ms/epoch - 17ms/step
# Epoch 243/300
#
# Epoch 243: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0744 - sparse_categorical_accuracy: 0.9692 - val_loss: 0.0900 - val_sparse_categorical_accuracy: 0.9880 - 243ms/epoch - 16ms/step
# Epoch 244/300
#
# Epoch 244: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0728 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0860 - val_sparse_categorical_accuracy: 0.9856 - 249ms/epoch - 17ms/step
# Epoch 245/300
#
# Epoch 245: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0756 - sparse_categorical_accuracy: 0.9813 - val_loss: 0.0921 - val_sparse_categorical_accuracy: 0.9856 - 233ms/epoch - 16ms/step
# Epoch 246/300
#
# Epoch 246: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0749 - sparse_categorical_accuracy: 0.9780 - val_loss: 0.0850 - val_sparse_categorical_accuracy: 0.9880 - 248ms/epoch - 17ms/step
# Epoch 247/300
#
# Epoch 247: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0548 - sparse_categorical_accuracy: 0.9813 - val_loss: 0.0936 - val_sparse_categorical_accuracy: 0.9880 - 229ms/epoch - 15ms/step
# Epoch 248/300
#
# Epoch 248: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0806 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.0870 - val_sparse_categorical_accuracy: 0.9880 - 250ms/epoch - 17ms/step
# Epoch 249/300
#
# Epoch 249: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0741 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.0859 - val_sparse_categorical_accuracy: 0.9856 - 248ms/epoch - 17ms/step
# Epoch 250/300
#
# Epoch 250: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0810 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0986 - val_sparse_categorical_accuracy: 0.9856 - 232ms/epoch - 15ms/step
# Epoch 251/300
#
# Epoch 251: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0706 - sparse_categorical_accuracy: 0.9791 - val_loss: 0.0867 - val_sparse_categorical_accuracy: 0.9880 - 235ms/epoch - 16ms/step
# Epoch 252/300
#
# Epoch 252: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0710 - sparse_categorical_accuracy: 0.9868 - val_loss: 0.0976 - val_sparse_categorical_accuracy: 0.9880 - 248ms/epoch - 17ms/step
# Epoch 253/300
#
# Epoch 253: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0587 - sparse_categorical_accuracy: 0.9813 - val_loss: 0.0999 - val_sparse_categorical_accuracy: 0.9880 - 248ms/epoch - 17ms/step
# Epoch 254/300
#
# Epoch 254: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0825 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.1045 - val_sparse_categorical_accuracy: 0.9856 - 230ms/epoch - 15ms/step
# Epoch 255/300
#
# Epoch 255: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0748 - sparse_categorical_accuracy: 0.9780 - val_loss: 0.0828 - val_sparse_categorical_accuracy: 0.9904 - 235ms/epoch - 16ms/step
# Epoch 256/300
#
# Epoch 256: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0824 - sparse_categorical_accuracy: 0.9692 - val_loss: 0.0920 - val_sparse_categorical_accuracy: 0.9880 - 250ms/epoch - 17ms/step
# Epoch 257/300
#
# Epoch 257: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0877 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0851 - val_sparse_categorical_accuracy: 0.9880 - 240ms/epoch - 16ms/step
# Epoch 258/300
#
# Epoch 258: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0691 - sparse_categorical_accuracy: 0.9769 - val_loss: 0.0843 - val_sparse_categorical_accuracy: 0.9880 - 246ms/epoch - 16ms/step
# Epoch 259/300
#
# Epoch 259: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0765 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.0888 - val_sparse_categorical_accuracy: 0.9880 - 248ms/epoch - 17ms/step
# Epoch 260/300
#
# Epoch 260: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0663 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.0859 - val_sparse_categorical_accuracy: 0.9880 - 277ms/epoch - 18ms/step
# Epoch 261/300
#
# Epoch 261: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0577 - sparse_categorical_accuracy: 0.9813 - val_loss: 0.0823 - val_sparse_categorical_accuracy: 0.9880 - 235ms/epoch - 16ms/step
# Epoch 262/300
#
# Epoch 262: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0858 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0833 - val_sparse_categorical_accuracy: 0.9928 - 235ms/epoch - 16ms/step
# Epoch 263/300
#
# Epoch 263: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0837 - sparse_categorical_accuracy: 0.9703 - val_loss: 0.0811 - val_sparse_categorical_accuracy: 0.9928 - 245ms/epoch - 16ms/step
# Epoch 264/300
#
# Epoch 264: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0752 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.0791 - val_sparse_categorical_accuracy: 0.9928 - 250ms/epoch - 17ms/step
# Epoch 265/300
#
# Epoch 265: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1173 - sparse_categorical_accuracy: 0.9604 - val_loss: 0.0823 - val_sparse_categorical_accuracy: 0.9904 - 243ms/epoch - 16ms/step
# Epoch 266/300
#
# Epoch 266: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1444 - sparse_categorical_accuracy: 0.9473 - val_loss: 0.0749 - val_sparse_categorical_accuracy: 0.9928 - 239ms/epoch - 16ms/step
# Epoch 267/300
#
# Epoch 267: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1227 - sparse_categorical_accuracy: 0.9604 - val_loss: 0.0841 - val_sparse_categorical_accuracy: 0.9928 - 241ms/epoch - 16ms/step
# Epoch 268/300
#
# Epoch 268: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1403 - sparse_categorical_accuracy: 0.9484 - val_loss: 0.0800 - val_sparse_categorical_accuracy: 0.9928 - 247ms/epoch - 16ms/step
# Epoch 269/300
#
# Epoch 269: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0915 - sparse_categorical_accuracy: 0.9703 - val_loss: 0.0750 - val_sparse_categorical_accuracy: 0.9928 - 241ms/epoch - 16ms/step
# Epoch 270/300
#
# Epoch 270: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0754 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0752 - val_sparse_categorical_accuracy: 0.9928 - 242ms/epoch - 16ms/step
# Epoch 271/300
#
# Epoch 271: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0914 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0737 - val_sparse_categorical_accuracy: 0.9928 - 239ms/epoch - 16ms/step
# Epoch 272/300
#
# Epoch 272: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0935 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.0803 - val_sparse_categorical_accuracy: 0.9904 - 245ms/epoch - 16ms/step
# Epoch 273/300
#
# Epoch 273: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0932 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.0795 - val_sparse_categorical_accuracy: 0.9928 - 246ms/epoch - 16ms/step
# Epoch 274/300
#
# Epoch 274: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0935 - sparse_categorical_accuracy: 0.9659 - val_loss: 0.0756 - val_sparse_categorical_accuracy: 0.9928 - 238ms/epoch - 16ms/step
# Epoch 275/300
#
# Epoch 275: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0710 - sparse_categorical_accuracy: 0.9780 - val_loss: 0.0797 - val_sparse_categorical_accuracy: 0.9928 - 233ms/epoch - 16ms/step
# Epoch 276/300
#
# Epoch 276: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0758 - sparse_categorical_accuracy: 0.9769 - val_loss: 0.0769 - val_sparse_categorical_accuracy: 0.9904 - 237ms/epoch - 16ms/step
# Epoch 277/300
#
# Epoch 277: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0890 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.0723 - val_sparse_categorical_accuracy: 0.9904 - 245ms/epoch - 16ms/step
# Epoch 278/300
#
# Epoch 278: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0911 - sparse_categorical_accuracy: 0.9648 - val_loss: 0.0723 - val_sparse_categorical_accuracy: 0.9904 - 239ms/epoch - 16ms/step
# Epoch 279/300
#
# Epoch 279: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0986 - sparse_categorical_accuracy: 0.9703 - val_loss: 0.0750 - val_sparse_categorical_accuracy: 0.9928 - 230ms/epoch - 15ms/step
# Epoch 280/300
#
# Epoch 280: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0742 - sparse_categorical_accuracy: 0.9780 - val_loss: 0.0771 - val_sparse_categorical_accuracy: 0.9928 - 243ms/epoch - 16ms/step
# Epoch 281/300
#
# Epoch 281: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0784 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0750 - val_sparse_categorical_accuracy: 0.9928 - 245ms/epoch - 16ms/step
# Epoch 282/300
#
# Epoch 282: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0929 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0766 - val_sparse_categorical_accuracy: 0.9928 - 241ms/epoch - 16ms/step
# Epoch 283/300
#
# Epoch 283: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0712 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.0725 - val_sparse_categorical_accuracy: 0.9928 - 236ms/epoch - 16ms/step
# Epoch 284/300
#
# Epoch 284: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0756 - sparse_categorical_accuracy: 0.9769 - val_loss: 0.0733 - val_sparse_categorical_accuracy: 0.9928 - 242ms/epoch - 16ms/step
# Epoch 285/300
#
# Epoch 285: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0771 - sparse_categorical_accuracy: 0.9780 - val_loss: 0.0727 - val_sparse_categorical_accuracy: 0.9928 - 241ms/epoch - 16ms/step
# Epoch 286/300
#
# Epoch 286: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0850 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0758 - val_sparse_categorical_accuracy: 0.9928 - 238ms/epoch - 16ms/step
# Epoch 287/300
#
# Epoch 287: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0635 - sparse_categorical_accuracy: 0.9791 - val_loss: 0.0740 - val_sparse_categorical_accuracy: 0.9928 - 238ms/epoch - 16ms/step
# Epoch 288/300
#
# Epoch 288: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0656 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.0708 - val_sparse_categorical_accuracy: 0.9928 - 235ms/epoch - 16ms/step
# Epoch 289/300
#
# Epoch 289: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0814 - sparse_categorical_accuracy: 0.9769 - val_loss: 0.0828 - val_sparse_categorical_accuracy: 0.9880 - 249ms/epoch - 17ms/step
# Epoch 290/300
#
# Epoch 290: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0767 - sparse_categorical_accuracy: 0.9791 - val_loss: 0.0788 - val_sparse_categorical_accuracy: 0.9904 - 239ms/epoch - 16ms/step
# Epoch 291/300
#
# Epoch 291: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0771 - sparse_categorical_accuracy: 0.9769 - val_loss: 0.0707 - val_sparse_categorical_accuracy: 0.9928 - 240ms/epoch - 16ms/step
# Epoch 292/300
#
# Epoch 292: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0916 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.0724 - val_sparse_categorical_accuracy: 0.9928 - 244ms/epoch - 16ms/step
# Epoch 293/300
#
# Epoch 293: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0768 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.0763 - val_sparse_categorical_accuracy: 0.9928 - 257ms/epoch - 17ms/step
# Epoch 294/300
#
# Epoch 294: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0511 - sparse_categorical_accuracy: 0.9868 - val_loss: 0.0779 - val_sparse_categorical_accuracy: 0.9904 - 254ms/epoch - 17ms/step
# Epoch 295/300
#
# Epoch 295: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0819 - sparse_categorical_accuracy: 0.9780 - val_loss: 0.0788 - val_sparse_categorical_accuracy: 0.9904 - 239ms/epoch - 16ms/step
# Epoch 296/300
#
# Epoch 296: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0806 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0777 - val_sparse_categorical_accuracy: 0.9904 - 235ms/epoch - 16ms/step
# Epoch 297/300
#
# Epoch 297: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0632 - sparse_categorical_accuracy: 0.9835 - val_loss: 0.0752 - val_sparse_categorical_accuracy: 0.9904 - 242ms/epoch - 16ms/step
# Epoch 298/300
#
# Epoch 298: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0547 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.0796 - val_sparse_categorical_accuracy: 0.9904 - 232ms/epoch - 15ms/step
# Epoch 299/300
#
# Epoch 299: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0592 - sparse_categorical_accuracy: 0.9813 - val_loss: 0.0758 - val_sparse_categorical_accuracy: 0.9928 - 234ms/epoch - 16ms/step
# Epoch 300/300
#
# Epoch 300: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0725 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.0798 - val_sparse_categorical_accuracy: 0.9928 - 242ms/epoch - 16ms/step
# 84.82928021299995 seconds

# %%
class Distiller(keras.Model):
    def __init__(self, student, teacher):
        super(Distiller, self).__init__()
        self.teacher = teacher
        self.student = student

    def compile(
        self,
        optimizer,
        metrics,
        student_loss_fn,
        distillation_loss_fn,
        alpha=0.1,
        temperature=10,
    ):
        """ Configure the distiller.

        Args:
            optimizer: Keras optimizer for the student weights
            metrics: Keras metrics for evaluation
            student_loss_fn: Loss function of difference between student
                predictions and ground-truth
            distillation_loss_fn: Loss function of difference between soft
                student predictions and soft teacher predictions
            alpha: weight to student_loss_fn and 1-alpha to distillation_loss_fn
            temperature: Temperature for softening probability distributions.
                Larger temperature gives softer distributions.
        """
        super(Distiller, self).compile(optimizer=optimizer, metrics=metrics)
        self.student_loss_fn = student_loss_fn
        self.distillation_loss_fn = distillation_loss_fn
        self.alpha = alpha
        self.temperature = temperature

    def train_step(self, data):
        # Unpack data
        x, y = data

        # Forward pass of teacher
        teacher_predictions = self.teacher(x, training=False)

        with tf.GradientTape() as tape:
            # Forward pass of student
            student_predictions = self.student(x, training=True)

            # Compute losses
            student_loss = self.student_loss_fn(y, student_predictions)

            # Compute scaled distillation loss from https://arxiv.org/abs/1503.02531
            # The magnitudes of the gradients produced by the soft targets scale
            # as 1/T^2, multiply them by T^2 when using both hard and soft targets.
            distillation_loss = (
                self.distillation_loss_fn(
                    tf.nn.softmax(teacher_predictions / self.temperature, axis=1),
                    tf.nn.softmax(student_predictions / self.temperature, axis=1),
                )
                * self.temperature**2
            )

            loss = self.alpha * student_loss + (1 - self.alpha) * distillation_loss

        # Compute gradients
        trainable_vars = self.student.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)

        # Update weights
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))

        # Update the metrics configured in `compile()`.
        self.compiled_metrics.update_state(y, student_predictions)

        # Return a dict of performance
        results = {m.name: m.result() for m in self.metrics}
        results.update(
            {"student_loss": student_loss, "distillation_loss": distillation_loss}
        )
        return results

    def test_step(self, data):
        # Unpack the data
        x, y = data

        # Compute predictions
        y_prediction = self.student(x, training=False)

        # Calculate the loss
        student_loss = self.student_loss_fn(y, y_prediction)

        # Update the metrics.
        self.compiled_metrics.update_state(y, y_prediction)

        # Return a dict of performance
        results = {m.name: m.result() for m in self.metrics}
        results.update({"student_loss": student_loss})
        return results

# %%
# Initialize and compile distiller
s_distiller = Distiller(student=student, teacher=teacher)
s_distiller.compile(
    optimizer=tensorflow.keras.optimizers.Adam(),
    metrics=[keras.metrics.SparseCategoricalAccuracy()],
    student_loss_fn=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    distillation_loss_fn=keras.losses.KLDivergence(),
    alpha=0.1,
    temperature=10,
)

historyt = s_distiller.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=50, batch_size=64, verbose=2)
#historys =  s_distiller.evaluate(x_test, y_test, batch_size=64, verbose=2)

hist_df = pd.DataFrame(historyt.history)

hist_csv_file = '15000historyBiLSTM20.csv'
with open(hist_csv_file, mode='w') as f:
    		hist_df.to_csv(f)
# Out:
# Epoch 1/50
# 15/15 - 5s - sparse_categorical_accuracy: 0.4143 - student_loss: 1.1063 - distillation_loss: 0.0946 - val_sparse_categorical_accuracy: 0.7356 - val_student_loss: 1.0921 - 5s/epoch - 328ms/step
# Epoch 2/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.4967 - student_loss: 1.0694 - distillation_loss: 0.1210 - val_sparse_categorical_accuracy: 0.9159 - val_student_loss: 0.9943 - 274ms/epoch - 18ms/step
# Epoch 3/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.5956 - student_loss: 0.9264 - distillation_loss: 0.1095 - val_sparse_categorical_accuracy: 0.9760 - val_student_loss: 0.9421 - 267ms/epoch - 18ms/step
# Epoch 4/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.6604 - student_loss: 0.9224 - distillation_loss: 0.1124 - val_sparse_categorical_accuracy: 0.9712 - val_student_loss: 0.9525 - 289ms/epoch - 19ms/step
# Epoch 5/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.6648 - student_loss: 1.0804 - distillation_loss: 0.1040 - val_sparse_categorical_accuracy: 0.9663 - val_student_loss: 0.9372 - 264ms/epoch - 18ms/step
# Epoch 6/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.6813 - student_loss: 1.1821 - distillation_loss: 0.1338 - val_sparse_categorical_accuracy: 0.9760 - val_student_loss: 0.9132 - 273ms/epoch - 18ms/step
# Epoch 7/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.7209 - student_loss: 0.9341 - distillation_loss: 0.1147 - val_sparse_categorical_accuracy: 0.9856 - val_student_loss: 0.8971 - 269ms/epoch - 18ms/step
# Epoch 8/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.7286 - student_loss: 0.9578 - distillation_loss: 0.0692 - val_sparse_categorical_accuracy: 0.9904 - val_student_loss: 0.8771 - 366ms/epoch - 24ms/step
# Epoch 9/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.7549 - student_loss: 0.9779 - distillation_loss: 0.1106 - val_sparse_categorical_accuracy: 0.9904 - val_student_loss: 0.8631 - 335ms/epoch - 22ms/step
# Epoch 10/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.7912 - student_loss: 0.8411 - distillation_loss: 0.0604 - val_sparse_categorical_accuracy: 0.9832 - val_student_loss: 0.8714 - 264ms/epoch - 18ms/step
# Epoch 11/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.8187 - student_loss: 0.9505 - distillation_loss: 0.0635 - val_sparse_categorical_accuracy: 0.9832 - val_student_loss: 0.8764 - 292ms/epoch - 19ms/step
# Epoch 12/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.8264 - student_loss: 0.9070 - distillation_loss: 0.0754 - val_sparse_categorical_accuracy: 0.9856 - val_student_loss: 0.8690 - 285ms/epoch - 19ms/step
# Epoch 13/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.8418 - student_loss: 0.8345 - distillation_loss: 0.0347 - val_sparse_categorical_accuracy: 0.9856 - val_student_loss: 0.8644 - 276ms/epoch - 18ms/step
# Epoch 14/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.8495 - student_loss: 0.8589 - distillation_loss: 0.0441 - val_sparse_categorical_accuracy: 0.9856 - val_student_loss: 0.8816 - 282ms/epoch - 19ms/step
# Epoch 15/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.8451 - student_loss: 0.9605 - distillation_loss: 0.0526 - val_sparse_categorical_accuracy: 0.9784 - val_student_loss: 0.8941 - 271ms/epoch - 18ms/step
# Epoch 16/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.8648 - student_loss: 0.9056 - distillation_loss: 0.0429 - val_sparse_categorical_accuracy: 0.9808 - val_student_loss: 0.8811 - 284ms/epoch - 19ms/step
# Epoch 17/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.8725 - student_loss: 1.0296 - distillation_loss: 0.0821 - val_sparse_categorical_accuracy: 0.9904 - val_student_loss: 0.8800 - 294ms/epoch - 20ms/step
# Epoch 18/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.8692 - student_loss: 0.7506 - distillation_loss: 0.0475 - val_sparse_categorical_accuracy: 0.9880 - val_student_loss: 0.8552 - 288ms/epoch - 19ms/step
# Epoch 19/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.8857 - student_loss: 0.9473 - distillation_loss: 0.0552 - val_sparse_categorical_accuracy: 0.9904 - val_student_loss: 0.8664 - 270ms/epoch - 18ms/step
# Epoch 20/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9000 - student_loss: 0.9245 - distillation_loss: 0.0485 - val_sparse_categorical_accuracy: 0.9904 - val_student_loss: 0.8615 - 273ms/epoch - 18ms/step
# Epoch 21/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9000 - student_loss: 0.9765 - distillation_loss: 0.0403 - val_sparse_categorical_accuracy: 0.9880 - val_student_loss: 0.8689 - 269ms/epoch - 18ms/step
# Epoch 22/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9297 - student_loss: 0.8526 - distillation_loss: 0.0315 - val_sparse_categorical_accuracy: 0.9832 - val_student_loss: 0.8615 - 264ms/epoch - 18ms/step
# Epoch 23/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9198 - student_loss: 0.9017 - distillation_loss: 0.0332 - val_sparse_categorical_accuracy: 0.9832 - val_student_loss: 0.8376 - 268ms/epoch - 18ms/step
# Epoch 24/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9253 - student_loss: 0.7552 - distillation_loss: 0.0291 - val_sparse_categorical_accuracy: 0.9880 - val_student_loss: 0.8469 - 265ms/epoch - 18ms/step
# Epoch 25/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9407 - student_loss: 0.8581 - distillation_loss: 0.0420 - val_sparse_categorical_accuracy: 0.9880 - val_student_loss: 0.8604 - 288ms/epoch - 19ms/step
# Epoch 26/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9308 - student_loss: 0.8709 - distillation_loss: 0.0308 - val_sparse_categorical_accuracy: 0.9856 - val_student_loss: 0.8565 - 265ms/epoch - 18ms/step
# Epoch 27/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9264 - student_loss: 0.8549 - distillation_loss: 0.0479 - val_sparse_categorical_accuracy: 0.9880 - val_student_loss: 0.8511 - 273ms/epoch - 18ms/step
# Epoch 28/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9341 - student_loss: 0.9779 - distillation_loss: 0.0420 - val_sparse_categorical_accuracy: 0.9856 - val_student_loss: 0.8599 - 277ms/epoch - 18ms/step
# Epoch 29/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9363 - student_loss: 0.8566 - distillation_loss: 0.0210 - val_sparse_categorical_accuracy: 0.9880 - val_student_loss: 0.8493 - 268ms/epoch - 18ms/step
# Epoch 30/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9385 - student_loss: 0.8741 - distillation_loss: 0.0439 - val_sparse_categorical_accuracy: 0.9880 - val_student_loss: 0.8415 - 271ms/epoch - 18ms/step
# Epoch 31/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9407 - student_loss: 0.8363 - distillation_loss: 0.0249 - val_sparse_categorical_accuracy: 0.9880 - val_student_loss: 0.8341 - 291ms/epoch - 19ms/step
# Epoch 32/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9242 - student_loss: 0.7344 - distillation_loss: 0.0371 - val_sparse_categorical_accuracy: 0.9880 - val_student_loss: 0.8371 - 298ms/epoch - 20ms/step
# Epoch 33/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9429 - student_loss: 0.8166 - distillation_loss: 0.0266 - val_sparse_categorical_accuracy: 0.9880 - val_student_loss: 0.8279 - 273ms/epoch - 18ms/step
# Epoch 34/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9264 - student_loss: 0.8155 - distillation_loss: 0.0319 - val_sparse_categorical_accuracy: 0.9880 - val_student_loss: 0.8451 - 275ms/epoch - 18ms/step
# Epoch 35/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9363 - student_loss: 0.9212 - distillation_loss: 0.0457 - val_sparse_categorical_accuracy: 0.9832 - val_student_loss: 0.8537 - 263ms/epoch - 18ms/step
# Epoch 36/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9484 - student_loss: 0.8033 - distillation_loss: 0.0394 - val_sparse_categorical_accuracy: 0.9880 - val_student_loss: 0.8330 - 269ms/epoch - 18ms/step
# Epoch 37/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9505 - student_loss: 0.8764 - distillation_loss: 0.0251 - val_sparse_categorical_accuracy: 0.9904 - val_student_loss: 0.8363 - 276ms/epoch - 18ms/step
# Epoch 38/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9385 - student_loss: 0.7866 - distillation_loss: 0.0533 - val_sparse_categorical_accuracy: 0.9856 - val_student_loss: 0.8421 - 272ms/epoch - 18ms/step
# Epoch 39/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9495 - student_loss: 0.8647 - distillation_loss: 0.0351 - val_sparse_categorical_accuracy: 0.9904 - val_student_loss: 0.8400 - 280ms/epoch - 19ms/step
# Epoch 40/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9516 - student_loss: 0.8822 - distillation_loss: 0.0296 - val_sparse_categorical_accuracy: 0.9928 - val_student_loss: 0.8367 - 275ms/epoch - 18ms/step
# Epoch 41/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9396 - student_loss: 0.8934 - distillation_loss: 0.0451 - val_sparse_categorical_accuracy: 0.9904 - val_student_loss: 0.8324 - 281ms/epoch - 19ms/step
# Epoch 42/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9538 - student_loss: 0.7953 - distillation_loss: 0.0345 - val_sparse_categorical_accuracy: 0.9904 - val_student_loss: 0.8358 - 273ms/epoch - 18ms/step
# Epoch 43/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9352 - student_loss: 0.8633 - distillation_loss: 0.0316 - val_sparse_categorical_accuracy: 0.9904 - val_student_loss: 0.8194 - 277ms/epoch - 18ms/step
# Epoch 44/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9484 - student_loss: 0.7483 - distillation_loss: 0.0247 - val_sparse_categorical_accuracy: 0.9904 - val_student_loss: 0.8215 - 265ms/epoch - 18ms/step
# Epoch 45/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9462 - student_loss: 0.7704 - distillation_loss: 0.0201 - val_sparse_categorical_accuracy: 0.9904 - val_student_loss: 0.8135 - 271ms/epoch - 18ms/step
# Epoch 46/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9648 - student_loss: 0.8584 - distillation_loss: 0.0350 - val_sparse_categorical_accuracy: 0.9904 - val_student_loss: 0.8219 - 256ms/epoch - 17ms/step
# Epoch 47/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9549 - student_loss: 0.7555 - distillation_loss: 0.0229 - val_sparse_categorical_accuracy: 0.9904 - val_student_loss: 0.8431 - 266ms/epoch - 18ms/step
# Epoch 48/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9440 - student_loss: 0.7855 - distillation_loss: 0.0276 - val_sparse_categorical_accuracy: 0.9904 - val_student_loss: 0.8373 - 298ms/epoch - 20ms/step
# Epoch 49/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9484 - student_loss: 0.9033 - distillation_loss: 0.0340 - val_sparse_categorical_accuracy: 0.9880 - val_student_loss: 0.8386 - 269ms/epoch - 18ms/step
# Epoch 50/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9462 - student_loss: 0.8803 - distillation_loss: 0.0208 - val_sparse_categorical_accuracy: 0.9880 - val_student_loss: 0.8371 - 267ms/epoch - 18ms/step

# %%
#Train student as does usually
student.compile(loss=tensorflow.keras.losses.sparse_categorical_crossentropy,
              optimizer=tensorflow.keras.optimizers.Adam(),
              metrics=[keras.metrics.SparseCategoricalAccuracy()])

student.save("student.h5")
teacher.save("teacher.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
#Train student as does usually
student_scratch.compile(loss=tensorflow.keras.losses.sparse_categorical_crossentropy,
              optimizer=tensorflow.keras.optimizers.Adam(),
              metrics=[keras.metrics.SparseCategoricalAccuracy()])

#checkpoint dan save weight untuk student scratch
filepath="weights.student_scratch.hdf5"
checkpoint_student_scratch = ModelCheckpoint(filepath, monitor='val_sparse_categorical_accuracy', verbose=1, save_best_only=True, mode='max')
#es_student_s = EarlyStopping(monitor='val_sparse_categorical_accuracy', patience=20)
callbacks_student_scratch_list = [checkpoint_student_scratch]

#Fit the model
student_scratch.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=50, batch_size=64, callbacks=callbacks_student_scratch_list, verbose=2)
# Out:
# Epoch 1/50
#
# Epoch 1: val_sparse_categorical_accuracy improved from -inf to 0.39663, saving model to weights.student_scratch.hdf5
# 15/15 - 4s - loss: 7.2332 - sparse_categorical_accuracy: 0.3165 - val_loss: 4.9821 - val_sparse_categorical_accuracy: 0.3966 - 4s/epoch - 252ms/step
# Epoch 2/50
#
# Epoch 2: val_sparse_categorical_accuracy improved from 0.39663 to 0.55048, saving model to weights.student_scratch.hdf5
# 15/15 - 0s - loss: 6.1561 - sparse_categorical_accuracy: 0.3560 - val_loss: 2.0303 - val_sparse_categorical_accuracy: 0.5505 - 289ms/epoch - 19ms/step
# Epoch 3/50
#
# Epoch 3: val_sparse_categorical_accuracy improved from 0.55048 to 0.64663, saving model to weights.student_scratch.hdf5
# 15/15 - 0s - loss: 5.0754 - sparse_categorical_accuracy: 0.3989 - val_loss: 1.3682 - val_sparse_categorical_accuracy: 0.6466 - 265ms/epoch - 18ms/step
# Epoch 4/50
#
# Epoch 4: val_sparse_categorical_accuracy improved from 0.64663 to 0.67067, saving model to weights.student_scratch.hdf5
# 15/15 - 0s - loss: 4.2267 - sparse_categorical_accuracy: 0.4418 - val_loss: 1.4170 - val_sparse_categorical_accuracy: 0.6707 - 216ms/epoch - 14ms/step
# Epoch 5/50
#
# Epoch 5: val_sparse_categorical_accuracy did not improve from 0.67067
# 15/15 - 0s - loss: 4.2436 - sparse_categorical_accuracy: 0.4604 - val_loss: 1.3130 - val_sparse_categorical_accuracy: 0.5697 - 204ms/epoch - 14ms/step
# Epoch 6/50
#
# Epoch 6: val_sparse_categorical_accuracy did not improve from 0.67067
# 15/15 - 0s - loss: 3.7858 - sparse_categorical_accuracy: 0.4330 - val_loss: 1.3830 - val_sparse_categorical_accuracy: 0.6106 - 194ms/epoch - 13ms/step
# Epoch 7/50
#
# Epoch 7: val_sparse_categorical_accuracy did not improve from 0.67067
# 15/15 - 0s - loss: 2.7856 - sparse_categorical_accuracy: 0.4593 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.6226 - 196ms/epoch - 13ms/step
# Epoch 8/50
#
# Epoch 8: val_sparse_categorical_accuracy did not improve from 0.67067
# 15/15 - 0s - loss: 2.8626 - sparse_categorical_accuracy: 0.4033 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.6346 - 204ms/epoch - 14ms/step
# Epoch 9/50
#
# Epoch 9: val_sparse_categorical_accuracy improved from 0.67067 to 0.68510, saving model to weights.student_scratch.hdf5
# 15/15 - 0s - loss: 2.3496 - sparse_categorical_accuracy: 0.4659 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.6851 - 243ms/epoch - 16ms/step
# Epoch 10/50
#
# Epoch 10: val_sparse_categorical_accuracy improved from 0.68510 to 0.74519, saving model to weights.student_scratch.hdf5
# 15/15 - 0s - loss: 2.1662 - sparse_categorical_accuracy: 0.4516 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.7452 - 243ms/epoch - 16ms/step
# Epoch 11/50
#
# Epoch 11: val_sparse_categorical_accuracy improved from 0.74519 to 0.76683, saving model to weights.student_scratch.hdf5
# 15/15 - 0s - loss: 1.7739 - sparse_categorical_accuracy: 0.4758 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.7668 - 233ms/epoch - 16ms/step
# Epoch 12/50
#
# Epoch 12: val_sparse_categorical_accuracy improved from 0.76683 to 0.78125, saving model to weights.student_scratch.hdf5
# 15/15 - 0s - loss: 1.9798 - sparse_categorical_accuracy: 0.4824 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.7812 - 257ms/epoch - 17ms/step
# Epoch 13/50
#
# Epoch 13: val_sparse_categorical_accuracy improved from 0.78125 to 0.80769, saving model to weights.student_scratch.hdf5
# 15/15 - 0s - loss: 1.8294 - sparse_categorical_accuracy: 0.4912 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.8077 - 214ms/epoch - 14ms/step
# Epoch 14/50
#
# Epoch 14: val_sparse_categorical_accuracy improved from 0.80769 to 0.81250, saving model to weights.student_scratch.hdf5
# 15/15 - 0s - loss: 1.8105 - sparse_categorical_accuracy: 0.4626 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.8125 - 283ms/epoch - 19ms/step
# Epoch 15/50
#
# Epoch 15: val_sparse_categorical_accuracy did not improve from 0.81250
# 15/15 - 0s - loss: 1.9423 - sparse_categorical_accuracy: 0.4363 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.7692 - 274ms/epoch - 18ms/step
# Epoch 16/50
#
# Epoch 16: val_sparse_categorical_accuracy did not improve from 0.81250
# 15/15 - 0s - loss: 1.7856 - sparse_categorical_accuracy: 0.4549 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.7308 - 274ms/epoch - 18ms/step
# Epoch 17/50
#
# Epoch 17: val_sparse_categorical_accuracy did not improve from 0.81250
# 15/15 - 0s - loss: 1.7685 - sparse_categorical_accuracy: 0.4495 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.6923 - 269ms/epoch - 18ms/step
# Epoch 18/50
#
# Epoch 18: val_sparse_categorical_accuracy did not improve from 0.81250
# 15/15 - 0s - loss: 1.7267 - sparse_categorical_accuracy: 0.4451 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.7019 - 262ms/epoch - 17ms/step
# Epoch 19/50
#
# Epoch 19: val_sparse_categorical_accuracy did not improve from 0.81250
# 15/15 - 0s - loss: 1.5200 - sparse_categorical_accuracy: 0.4582 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.7115 - 287ms/epoch - 19ms/step
# Epoch 20/50
#
# Epoch 20: val_sparse_categorical_accuracy did not improve from 0.81250
# 15/15 - 0s - loss: 1.6167 - sparse_categorical_accuracy: 0.4659 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.6683 - 261ms/epoch - 17ms/step
# Epoch 21/50
#
# Epoch 21: val_sparse_categorical_accuracy did not improve from 0.81250
# 15/15 - 0s - loss: 1.7216 - sparse_categorical_accuracy: 0.4615 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.6370 - 280ms/epoch - 19ms/step
# Epoch 22/50
#
# Epoch 22: val_sparse_categorical_accuracy did not improve from 0.81250
# 15/15 - 0s - loss: 1.7558 - sparse_categorical_accuracy: 0.4286 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.6851 - 283ms/epoch - 19ms/step
# Epoch 23/50
#
# Epoch 23: val_sparse_categorical_accuracy did not improve from 0.81250
# 15/15 - 0s - loss: 1.5037 - sparse_categorical_accuracy: 0.4440 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.7139 - 268ms/epoch - 18ms/step
# Epoch 24/50
#
# Epoch 24: val_sparse_categorical_accuracy did not improve from 0.81250
# 15/15 - 0s - loss: 1.5872 - sparse_categorical_accuracy: 0.4758 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.7212 - 262ms/epoch - 17ms/step
# Epoch 25/50
#
# Epoch 25: val_sparse_categorical_accuracy did not improve from 0.81250
# 15/15 - 0s - loss: 1.5240 - sparse_categorical_accuracy: 0.4319 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.7139 - 264ms/epoch - 18ms/step
# Epoch 26/50
#
# Epoch 26: val_sparse_categorical_accuracy did not improve from 0.81250
# 15/15 - 0s - loss: 1.5080 - sparse_categorical_accuracy: 0.4440 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.7019 - 272ms/epoch - 18ms/step
# Epoch 27/50
#
# Epoch 27: val_sparse_categorical_accuracy did not improve from 0.81250
# 15/15 - 0s - loss: 1.5635 - sparse_categorical_accuracy: 0.4527 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.7043 - 229ms/epoch - 15ms/step
# Epoch 28/50
#
# Epoch 28: val_sparse_categorical_accuracy did not improve from 0.81250
# 15/15 - 0s - loss: 1.5470 - sparse_categorical_accuracy: 0.4593 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.6611 - 184ms/epoch - 12ms/step
# Epoch 29/50
#
# Epoch 29: val_sparse_categorical_accuracy did not improve from 0.81250
# 15/15 - 0s - loss: 1.5343 - sparse_categorical_accuracy: 0.4440 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.6683 - 192ms/epoch - 13ms/step
# Epoch 30/50
#
# Epoch 30: val_sparse_categorical_accuracy did not improve from 0.81250
# 15/15 - 0s - loss: 1.5854 - sparse_categorical_accuracy: 0.4637 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.6755 - 204ms/epoch - 14ms/step
# Epoch 31/50
#
# Epoch 31: val_sparse_categorical_accuracy did not improve from 0.81250
# 15/15 - 0s - loss: 1.4618 - sparse_categorical_accuracy: 0.4363 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.6755 - 208ms/epoch - 14ms/step
# Epoch 32/50
#
# Epoch 32: val_sparse_categorical_accuracy did not improve from 0.81250
# 15/15 - 0s - loss: 1.5619 - sparse_categorical_accuracy: 0.4495 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.6418 - 200ms/epoch - 13ms/step
# Epoch 33/50
#
# Epoch 33: val_sparse_categorical_accuracy did not improve from 0.81250
# 15/15 - 0s - loss: 1.5138 - sparse_categorical_accuracy: 0.4670 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.6298 - 194ms/epoch - 13ms/step
# Epoch 34/50
#
# Epoch 34: val_sparse_categorical_accuracy did not improve from 0.81250
# 15/15 - 0s - loss: 1.5229 - sparse_categorical_accuracy: 0.4462 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.6154 - 196ms/epoch - 13ms/step
# Epoch 35/50
#
# Epoch 35: val_sparse_categorical_accuracy did not improve from 0.81250
# 15/15 - 0s - loss: 1.5204 - sparse_categorical_accuracy: 0.4308 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.6130 - 196ms/epoch - 13ms/step
# Epoch 36/50
#
# Epoch 36: val_sparse_categorical_accuracy did not improve from 0.81250
# 15/15 - 0s - loss: 1.4972 - sparse_categorical_accuracy: 0.4473 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.5865 - 199ms/epoch - 13ms/step
# Epoch 37/50
#
# Epoch 37: val_sparse_categorical_accuracy did not improve from 0.81250
# 15/15 - 0s - loss: 1.5893 - sparse_categorical_accuracy: 0.4538 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.5913 - 208ms/epoch - 14ms/step
# Epoch 38/50
#
# Epoch 38: val_sparse_categorical_accuracy did not improve from 0.81250
# 15/15 - 0s - loss: 1.4527 - sparse_categorical_accuracy: 0.4275 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.5409 - 193ms/epoch - 13ms/step
# Epoch 39/50
#
# Epoch 39: val_sparse_categorical_accuracy did not improve from 0.81250
# 15/15 - 0s - loss: 1.5482 - sparse_categorical_accuracy: 0.3967 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.5721 - 194ms/epoch - 13ms/step
# Epoch 40/50
#
# Epoch 40: val_sparse_categorical_accuracy did not improve from 0.81250
# 15/15 - 0s - loss: 1.5111 - sparse_categorical_accuracy: 0.4242 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.6274 - 202ms/epoch - 13ms/step
# Epoch 41/50
#
# Epoch 41: val_sparse_categorical_accuracy did not improve from 0.81250
# 15/15 - 0s - loss: 1.4425 - sparse_categorical_accuracy: 0.4143 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.6250 - 205ms/epoch - 14ms/step
# Epoch 42/50
#
# Epoch 42: val_sparse_categorical_accuracy did not improve from 0.81250
# 15/15 - 0s - loss: 1.5031 - sparse_categorical_accuracy: 0.4088 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.6394 - 192ms/epoch - 13ms/step
# Epoch 43/50
#
# Epoch 43: val_sparse_categorical_accuracy did not improve from 0.81250
# 15/15 - 0s - loss: 1.4942 - sparse_categorical_accuracy: 0.4308 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.6418 - 191ms/epoch - 13ms/step
# Epoch 44/50
#
# Epoch 44: val_sparse_categorical_accuracy did not improve from 0.81250
# 15/15 - 0s - loss: 1.4546 - sparse_categorical_accuracy: 0.4187 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.6034 - 205ms/epoch - 14ms/step
# Epoch 45/50
#
# Epoch 45: val_sparse_categorical_accuracy did not improve from 0.81250
# 15/15 - 0s - loss: 1.5147 - sparse_categorical_accuracy: 0.4286 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.6250 - 189ms/epoch - 13ms/step
# Epoch 46/50
#
# Epoch 46: val_sparse_categorical_accuracy did not improve from 0.81250
# 15/15 - 0s - loss: 1.4500 - sparse_categorical_accuracy: 0.4121 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.6418 - 219ms/epoch - 15ms/step
# Epoch 47/50
#
# Epoch 47: val_sparse_categorical_accuracy did not improve from 0.81250
# 15/15 - 0s - loss: 1.4192 - sparse_categorical_accuracy: 0.4044 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.6971 - 199ms/epoch - 13ms/step
# Epoch 48/50
#
# Epoch 48: val_sparse_categorical_accuracy did not improve from 0.81250
# 15/15 - 0s - loss: 1.4872 - sparse_categorical_accuracy: 0.4011 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.6875 - 194ms/epoch - 13ms/step
# Epoch 49/50
#
# Epoch 49: val_sparse_categorical_accuracy did not improve from 0.81250
# 15/15 - 0s - loss: 1.4270 - sparse_categorical_accuracy: 0.4451 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.6971 - 191ms/epoch - 13ms/step
# Epoch 50/50
#
# Epoch 50: val_sparse_categorical_accuracy did not improve from 0.81250
# 15/15 - 0s - loss: 1.4777 - sparse_categorical_accuracy: 0.4154 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.7332 - 209ms/epoch - 14ms/step

# %% [markdown]
# ## ***Predict***

# %%
from tensorflow.keras.models import load_model

# load model
teachers = tf.keras.models.load_model("/content/teacher.h5")
teachers.load_weights("/content/teacher.h5")

# %%
teachers.summary()
# Out:
# Model: "teacher"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 200)              88800
#  l)
#
#  dropout (Dropout)           (None, 200)               0
#
#  dense (Dense)               (None, 100)               20100
#
#  dense_1 (Dense)             (None, 4)                 404
#
# =================================================================
# Total params: 109,304
# Trainable params: 109,304
# Non-trainable params: 0
# _________________________________________________________________

# %%
start_time = time.process_time()
teachers.predict(x_test)
print (time.process_time() - start_time, "seconds")
# Out:
# 13/13 [==============================] - 1s 7ms/step
# 0.8459418889999881 seconds

# %%
from tensorflow.keras.models import load_model
 
# load model
students = tf.keras.models.load_model("/content/student.h5")
students.load_weights("/content/student.h5")

# %%
students.summary()
# Out:
# Model: "student"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (None, 94)               21808
#  nal)
#
#  dropout_1 (Dropout)         (None, 94)                0
#
#  dense_2 (Dense)             (None, 4)                 380
#
# =================================================================
# Total params: 22,188
# Trainable params: 22,188
# Non-trainable params: 0
# _________________________________________________________________

# %%
start_time = time.process_time()
students.predict(x_test)
print (time.process_time() - start_time, "seconds")
# Out:
# 13/13 [==============================] - 1s 6ms/step
# 0.8283951010000123 seconds

# %%
#Play an audio beep.
from google.colab import output
output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')

# %%
#start_time = time.perf_counter()
#y_pred_student = students.predict(x_test)
#print(y_pred)
#print (time.perf_counter() - start_time, "seconds")

# %%
#start_time = time.perf_counter()
#y_pred_teacher = teachers.predict(x_test)
#print(y_pred_teacher)
#print (time.perf_counter() - start_time, "seconds"
