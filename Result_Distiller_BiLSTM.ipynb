# %% [markdown]
# <a href="https://colab.research.google.com/github/iqbalkap/PruningDistillation/blob/main/Result_Distiller_BiLSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Knowledge Distillation**

# %%
import tensorflow as tf
import os
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.callbacks import ModelCheckpoint
import pandas as pd
import tensorflow
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.layers import (
    LSTM,
    Dense,
    Flatten,
    Dropout,
    BatchNormalization,
    Bidirectional
    )


train = pd.read_csv('/content/drive/MyDrive/Dataset VAE/uncalibrated/train_final_u/train_21_u.csv')
test = pd.read_csv('/content/drive/MyDrive/Dataset VAE/uncalibrated/valid_final_u/valid_21_u.csv')


#del variabel yang tidak dipakai
train = train.drop(['Timestamp', 'Cycle', 'Active Button'], axis=1)
test = test.drop(['Timestamp', 'Cycle', 'Active Button'], axis=1)

print('Input train shape :', train.shape)
print('Input test shape :', test.shape)
# Out:
# Input train shape : (91000, 10)
# Input test shape : (41600, 10)

# %%
# Prepare the train and test dataset.

n_ts = 100 #bebas
n_outputs = 4
n_features = 10

x_train = (train.values[:,0:10])
xt = int(x_train.shape[0]/n_ts) #ubah ke 3D
print('x_train_samples =',xt)
x_train = x_train.reshape((xt, n_ts, 10))
x_train = x_train.astype('float32')
y_train = pd.read_csv('/content/drive/MyDrive/Dataset VAE/hasil_labeling_train_u.csv') #label train
y_train = y_train.astype('float32')

x_test = (test.values[:,0:10])
xs = int(x_test.shape[0]/n_ts)
print('x_test_samples =',xs)
x_test = x_test.reshape((xs,n_ts,10))
x_test = x_test.astype('float32')
y_test = pd.read_csv('/content/drive/MyDrive/Dataset VAE/hasil_labeling_valid_u.csv') #label test
y_test = y_test.astype('float32')

######################
y_train = y_train - 1
y_test = y_test - 1

print('Shape final')
x_train.shape,y_train.shape, x_test.shape, y_test.shape
# Out:
# x_train_samples = 910
# x_test_samples = 416
# Shape final
# ((910, 100, 10), (910, 1), (416, 100, 10), (416, 1))

# %%
# Create the teacher's model
teacher = keras.Sequential(
    [
        keras.Input(shape=(n_ts,n_features)),
        layers.Bidirectional(LSTM(100, activation='tanh')),
        layers.Dropout(0.5),
        layers.Dense(100, activation='relu'),
        layers.Dense(n_outputs, activation='softmax'),
    ],

    name="teacher",
)
teacher.summary()
# Out:
# Model: "teacher"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 200)              88800
#  l)
#
#  dropout (Dropout)           (None, 200)               0
#
#  dense (Dense)               (None, 100)               20100
#
#  dense_1 (Dense)             (None, 4)                 404
#
# =================================================================
# Total params: 109,304
# Trainable params: 109,304
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Create the student's model
student = keras.Sequential(
    [
        keras.Input(shape=(n_ts,n_features)),
        layers.Bidirectional(LSTM(47, activation='tanh')),
        layers.Dropout(0.5),
        layers.Dense(n_outputs),
    ],
    name="student",
)
student.summary()
# Out:
# Model: "student"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (None, 94)               21808
#  nal)
#
#  dropout_1 (Dropout)         (None, 94)                0
#
#  dense_2 (Dense)             (None, 4)                 380
#
# =================================================================
# Total params: 22,188
# Trainable params: 22,188
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Clone student for later comparison
student_scratch = keras.models.clone_model(student)

# %%
import time

start_time = time.perf_counter()

# Train teacher as usual
teacher.compile(loss=tensorflow.keras.losses.sparse_categorical_crossentropy,
              optimizer=tensorflow.keras.optimizers.Adam(),
              metrics=[keras.metrics.SparseCategoricalAccuracy()])

#checkpoint dan save weight untuk teacher
filepath="weights.teacher.hdf5"
checkpoint_teacher = ModelCheckpoint(filepath, monitor='val_sparse_categorical_accuracy', verbose=1, save_best_only=True, mode='max')
#es_teacher = EarlyStopping(monitor='val_sparse_categorical_accuracy', patience=10)
callbacks_teacher_list = [checkpoint_teacher]



#Run teacher RUN!!!
#Fit the model
history = teacher.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=300, batch_size=64, callbacks=callbacks_teacher_list, verbose=2)

print (time.perf_counter() - start_time, "seconds")
# Out:
# Epoch 1/300
#
# Epoch 1: val_sparse_categorical_accuracy improved from -inf to 0.81971, saving model to weights.teacher.hdf5
# 15/15 - 10s - loss: 1.1152 - sparse_categorical_accuracy: 0.5505 - val_loss: 0.6365 - val_sparse_categorical_accuracy: 0.8197 - 10s/epoch - 658ms/step
# Epoch 2/300
#
# Epoch 2: val_sparse_categorical_accuracy improved from 0.81971 to 0.96635, saving model to weights.teacher.hdf5
# 15/15 - 0s - loss: 0.5735 - sparse_categorical_accuracy: 0.8571 - val_loss: 0.2927 - val_sparse_categorical_accuracy: 0.9663 - 281ms/epoch - 19ms/step
# Epoch 3/300
#
# Epoch 3: val_sparse_categorical_accuracy improved from 0.96635 to 0.98317, saving model to weights.teacher.hdf5
# 15/15 - 0s - loss: 0.3344 - sparse_categorical_accuracy: 0.9308 - val_loss: 0.1389 - val_sparse_categorical_accuracy: 0.9832 - 281ms/epoch - 19ms/step
# Epoch 4/300
#
# Epoch 4: val_sparse_categorical_accuracy improved from 0.98317 to 0.98798, saving model to weights.teacher.hdf5
# 15/15 - 0s - loss: 0.2171 - sparse_categorical_accuracy: 0.9582 - val_loss: 0.0826 - val_sparse_categorical_accuracy: 0.9880 - 270ms/epoch - 18ms/step
# Epoch 5/300
#
# Epoch 5: val_sparse_categorical_accuracy improved from 0.98798 to 0.99038, saving model to weights.teacher.hdf5
# 15/15 - 0s - loss: 0.1526 - sparse_categorical_accuracy: 0.9626 - val_loss: 0.0623 - val_sparse_categorical_accuracy: 0.9904 - 278ms/epoch - 19ms/step
# Epoch 6/300
#
# Epoch 6: val_sparse_categorical_accuracy did not improve from 0.99038
# 15/15 - 0s - loss: 0.1456 - sparse_categorical_accuracy: 0.9692 - val_loss: 0.0546 - val_sparse_categorical_accuracy: 0.9904 - 252ms/epoch - 17ms/step
# Epoch 7/300
#
# Epoch 7: val_sparse_categorical_accuracy did not improve from 0.99038
# 15/15 - 0s - loss: 0.1230 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0572 - val_sparse_categorical_accuracy: 0.9904 - 243ms/epoch - 16ms/step
# Epoch 8/300
#
# Epoch 8: val_sparse_categorical_accuracy did not improve from 0.99038
# 15/15 - 0s - loss: 0.1056 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0505 - val_sparse_categorical_accuracy: 0.9904 - 256ms/epoch - 17ms/step
# Epoch 9/300
#
# Epoch 9: val_sparse_categorical_accuracy did not improve from 0.99038
# 15/15 - 0s - loss: 0.0963 - sparse_categorical_accuracy: 0.9780 - val_loss: 0.0565 - val_sparse_categorical_accuracy: 0.9904 - 252ms/epoch - 17ms/step
# Epoch 10/300
#
# Epoch 10: val_sparse_categorical_accuracy did not improve from 0.99038
# 15/15 - 0s - loss: 0.1086 - sparse_categorical_accuracy: 0.9769 - val_loss: 0.0614 - val_sparse_categorical_accuracy: 0.9904 - 241ms/epoch - 16ms/step
# Epoch 11/300
#
# Epoch 11: val_sparse_categorical_accuracy did not improve from 0.99038
# 15/15 - 0s - loss: 0.1115 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0651 - val_sparse_categorical_accuracy: 0.9904 - 241ms/epoch - 16ms/step
# Epoch 12/300
#
# Epoch 12: val_sparse_categorical_accuracy improved from 0.99038 to 0.99279, saving model to weights.teacher.hdf5
# 15/15 - 0s - loss: 0.1235 - sparse_categorical_accuracy: 0.9626 - val_loss: 0.0515 - val_sparse_categorical_accuracy: 0.9928 - 270ms/epoch - 18ms/step
# Epoch 13/300
#
# Epoch 13: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1002 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.0494 - val_sparse_categorical_accuracy: 0.9928 - 245ms/epoch - 16ms/step
# Epoch 14/300
#
# Epoch 14: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1095 - sparse_categorical_accuracy: 0.9769 - val_loss: 0.0528 - val_sparse_categorical_accuracy: 0.9904 - 239ms/epoch - 16ms/step
# Epoch 15/300
#
# Epoch 15: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1087 - sparse_categorical_accuracy: 0.9692 - val_loss: 0.0584 - val_sparse_categorical_accuracy: 0.9880 - 244ms/epoch - 16ms/step
# Epoch 16/300
#
# Epoch 16: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0943 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0593 - val_sparse_categorical_accuracy: 0.9880 - 237ms/epoch - 16ms/step
# Epoch 17/300
#
# Epoch 17: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0974 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.0647 - val_sparse_categorical_accuracy: 0.9880 - 252ms/epoch - 17ms/step
# Epoch 18/300
#
# Epoch 18: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0983 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.0540 - val_sparse_categorical_accuracy: 0.9928 - 247ms/epoch - 16ms/step
# Epoch 19/300
#
# Epoch 19: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0815 - sparse_categorical_accuracy: 0.9780 - val_loss: 0.0617 - val_sparse_categorical_accuracy: 0.9904 - 242ms/epoch - 16ms/step
# Epoch 20/300
#
# Epoch 20: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0858 - sparse_categorical_accuracy: 0.9681 - val_loss: 0.0536 - val_sparse_categorical_accuracy: 0.9904 - 242ms/epoch - 16ms/step
# Epoch 21/300
#
# Epoch 21: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0904 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0524 - val_sparse_categorical_accuracy: 0.9928 - 251ms/epoch - 17ms/step
# Epoch 22/300
#
# Epoch 22: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0905 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.0510 - val_sparse_categorical_accuracy: 0.9928 - 246ms/epoch - 16ms/step
# Epoch 23/300
#
# Epoch 23: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0819 - sparse_categorical_accuracy: 0.9780 - val_loss: 0.0550 - val_sparse_categorical_accuracy: 0.9880 - 241ms/epoch - 16ms/step
# Epoch 24/300
#
# Epoch 24: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1003 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0606 - val_sparse_categorical_accuracy: 0.9904 - 236ms/epoch - 16ms/step
# Epoch 25/300
#
# Epoch 25: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0713 - sparse_categorical_accuracy: 0.9813 - val_loss: 0.0525 - val_sparse_categorical_accuracy: 0.9928 - 246ms/epoch - 16ms/step
# Epoch 26/300
#
# Epoch 26: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0812 - sparse_categorical_accuracy: 0.9791 - val_loss: 0.0527 - val_sparse_categorical_accuracy: 0.9928 - 242ms/epoch - 16ms/step
# Epoch 27/300
#
# Epoch 27: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0962 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0538 - val_sparse_categorical_accuracy: 0.9904 - 249ms/epoch - 17ms/step
# Epoch 28/300
#
# Epoch 28: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0805 - sparse_categorical_accuracy: 0.9780 - val_loss: 0.0502 - val_sparse_categorical_accuracy: 0.9904 - 241ms/epoch - 16ms/step
# Epoch 29/300
#
# Epoch 29: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0964 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0588 - val_sparse_categorical_accuracy: 0.9904 - 255ms/epoch - 17ms/step
# Epoch 30/300
#
# Epoch 30: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0850 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.0614 - val_sparse_categorical_accuracy: 0.9856 - 247ms/epoch - 16ms/step
# Epoch 31/300
#
# Epoch 31: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0936 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0592 - val_sparse_categorical_accuracy: 0.9880 - 239ms/epoch - 16ms/step
# Epoch 32/300
#
# Epoch 32: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0761 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0485 - val_sparse_categorical_accuracy: 0.9904 - 260ms/epoch - 17ms/step
# Epoch 33/300
#
# Epoch 33: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0835 - sparse_categorical_accuracy: 0.9857 - val_loss: 0.0574 - val_sparse_categorical_accuracy: 0.9904 - 248ms/epoch - 17ms/step
# Epoch 34/300
#
# Epoch 34: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0938 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0585 - val_sparse_categorical_accuracy: 0.9928 - 250ms/epoch - 17ms/step
# Epoch 35/300
#
# Epoch 35: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0896 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.0563 - val_sparse_categorical_accuracy: 0.9904 - 244ms/epoch - 16ms/step
# Epoch 36/300
#
# Epoch 36: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1042 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0527 - val_sparse_categorical_accuracy: 0.9928 - 243ms/epoch - 16ms/step
# Epoch 37/300
#
# Epoch 37: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0988 - sparse_categorical_accuracy: 0.9703 - val_loss: 0.0536 - val_sparse_categorical_accuracy: 0.9904 - 249ms/epoch - 17ms/step
# Epoch 38/300
#
# Epoch 38: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1163 - sparse_categorical_accuracy: 0.9648 - val_loss: 0.0517 - val_sparse_categorical_accuracy: 0.9904 - 245ms/epoch - 16ms/step
# Epoch 39/300
#
# Epoch 39: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1068 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.0620 - val_sparse_categorical_accuracy: 0.9880 - 236ms/epoch - 16ms/step
# Epoch 40/300
#
# Epoch 40: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1321 - sparse_categorical_accuracy: 0.9615 - val_loss: 0.0596 - val_sparse_categorical_accuracy: 0.9880 - 244ms/epoch - 16ms/step
# Epoch 41/300
#
# Epoch 41: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1231 - sparse_categorical_accuracy: 0.9659 - val_loss: 0.0646 - val_sparse_categorical_accuracy: 0.9856 - 248ms/epoch - 17ms/step
# Epoch 42/300
#
# Epoch 42: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1037 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.0664 - val_sparse_categorical_accuracy: 0.9856 - 243ms/epoch - 16ms/step
# Epoch 43/300
#
# Epoch 43: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1084 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.0662 - val_sparse_categorical_accuracy: 0.9856 - 239ms/epoch - 16ms/step
# Epoch 44/300
#
# Epoch 44: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1018 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0576 - val_sparse_categorical_accuracy: 0.9904 - 240ms/epoch - 16ms/step
# Epoch 45/300
#
# Epoch 45: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0998 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.0595 - val_sparse_categorical_accuracy: 0.9880 - 242ms/epoch - 16ms/step
# Epoch 46/300
#
# Epoch 46: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1012 - sparse_categorical_accuracy: 0.9692 - val_loss: 0.0634 - val_sparse_categorical_accuracy: 0.9856 - 246ms/epoch - 16ms/step
# Epoch 47/300
#
# Epoch 47: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1063 - sparse_categorical_accuracy: 0.9637 - val_loss: 0.0578 - val_sparse_categorical_accuracy: 0.9880 - 235ms/epoch - 16ms/step
# Epoch 48/300
#
# Epoch 48: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1091 - sparse_categorical_accuracy: 0.9703 - val_loss: 0.0580 - val_sparse_categorical_accuracy: 0.9904 - 235ms/epoch - 16ms/step
# Epoch 49/300
#
# Epoch 49: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1033 - sparse_categorical_accuracy: 0.9681 - val_loss: 0.0503 - val_sparse_categorical_accuracy: 0.9904 - 238ms/epoch - 16ms/step
# Epoch 50/300
#
# Epoch 50: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0867 - sparse_categorical_accuracy: 0.9769 - val_loss: 0.0516 - val_sparse_categorical_accuracy: 0.9904 - 249ms/epoch - 17ms/step
# Epoch 51/300
#
# Epoch 51: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0814 - sparse_categorical_accuracy: 0.9791 - val_loss: 0.0546 - val_sparse_categorical_accuracy: 0.9904 - 249ms/epoch - 17ms/step
# Epoch 52/300
#
# Epoch 52: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0899 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.0640 - val_sparse_categorical_accuracy: 0.9880 - 237ms/epoch - 16ms/step
# Epoch 53/300
#
# Epoch 53: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0940 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.0626 - val_sparse_categorical_accuracy: 0.9880 - 240ms/epoch - 16ms/step
# Epoch 54/300
#
# Epoch 54: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1016 - sparse_categorical_accuracy: 0.9659 - val_loss: 0.0577 - val_sparse_categorical_accuracy: 0.9880 - 269ms/epoch - 18ms/step
# Epoch 55/300
#
# Epoch 55: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0940 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0614 - val_sparse_categorical_accuracy: 0.9856 - 241ms/epoch - 16ms/step
# Epoch 56/300
#
# Epoch 56: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0895 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0672 - val_sparse_categorical_accuracy: 0.9856 - 239ms/epoch - 16ms/step
# Epoch 57/300
#
# Epoch 57: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1099 - sparse_categorical_accuracy: 0.9703 - val_loss: 0.0541 - val_sparse_categorical_accuracy: 0.9904 - 237ms/epoch - 16ms/step
# Epoch 58/300
#
# Epoch 58: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1035 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0534 - val_sparse_categorical_accuracy: 0.9880 - 251ms/epoch - 17ms/step
# Epoch 59/300
#
# Epoch 59: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1119 - sparse_categorical_accuracy: 0.9626 - val_loss: 0.0581 - val_sparse_categorical_accuracy: 0.9880 - 253ms/epoch - 17ms/step
# Epoch 60/300
#
# Epoch 60: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0921 - sparse_categorical_accuracy: 0.9791 - val_loss: 0.0529 - val_sparse_categorical_accuracy: 0.9880 - 241ms/epoch - 16ms/step
# Epoch 61/300
#
# Epoch 61: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0990 - sparse_categorical_accuracy: 0.9681 - val_loss: 0.0592 - val_sparse_categorical_accuracy: 0.9928 - 235ms/epoch - 16ms/step
# Epoch 62/300
#
# Epoch 62: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0803 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.0648 - val_sparse_categorical_accuracy: 0.9904 - 257ms/epoch - 17ms/step
# Epoch 63/300
#
# Epoch 63: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0850 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0665 - val_sparse_categorical_accuracy: 0.9880 - 241ms/epoch - 16ms/step
# Epoch 64/300
#
# Epoch 64: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1059 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.0597 - val_sparse_categorical_accuracy: 0.9928 - 236ms/epoch - 16ms/step
# Epoch 65/300
#
# Epoch 65: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1162 - sparse_categorical_accuracy: 0.9703 - val_loss: 0.0611 - val_sparse_categorical_accuracy: 0.9904 - 234ms/epoch - 16ms/step
# Epoch 66/300
#
# Epoch 66: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0983 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0594 - val_sparse_categorical_accuracy: 0.9904 - 253ms/epoch - 17ms/step
# Epoch 67/300
#
# Epoch 67: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1074 - sparse_categorical_accuracy: 0.9648 - val_loss: 0.0552 - val_sparse_categorical_accuracy: 0.9928 - 232ms/epoch - 15ms/step
# Epoch 68/300
#
# Epoch 68: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0878 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.0591 - val_sparse_categorical_accuracy: 0.9880 - 235ms/epoch - 16ms/step
# Epoch 69/300
#
# Epoch 69: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1100 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0549 - val_sparse_categorical_accuracy: 0.9904 - 239ms/epoch - 16ms/step
# Epoch 70/300
#
# Epoch 70: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1013 - sparse_categorical_accuracy: 0.9681 - val_loss: 0.0647 - val_sparse_categorical_accuracy: 0.9904 - 250ms/epoch - 17ms/step
# Epoch 71/300
#
# Epoch 71: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0800 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.0641 - val_sparse_categorical_accuracy: 0.9904 - 236ms/epoch - 16ms/step
# Epoch 72/300
#
# Epoch 72: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0846 - sparse_categorical_accuracy: 0.9769 - val_loss: 0.0634 - val_sparse_categorical_accuracy: 0.9904 - 251ms/epoch - 17ms/step
# Epoch 73/300
#
# Epoch 73: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1100 - sparse_categorical_accuracy: 0.9659 - val_loss: 0.0546 - val_sparse_categorical_accuracy: 0.9928 - 234ms/epoch - 16ms/step
# Epoch 74/300
#
# Epoch 74: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0902 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0539 - val_sparse_categorical_accuracy: 0.9928 - 258ms/epoch - 17ms/step
# Epoch 75/300
#
# Epoch 75: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1006 - sparse_categorical_accuracy: 0.9626 - val_loss: 0.0556 - val_sparse_categorical_accuracy: 0.9928 - 246ms/epoch - 16ms/step
# Epoch 76/300
#
# Epoch 76: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1030 - sparse_categorical_accuracy: 0.9681 - val_loss: 0.0610 - val_sparse_categorical_accuracy: 0.9928 - 232ms/epoch - 15ms/step
# Epoch 77/300
#
# Epoch 77: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0754 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0600 - val_sparse_categorical_accuracy: 0.9904 - 249ms/epoch - 17ms/step
# Epoch 78/300
#
# Epoch 78: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0938 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0564 - val_sparse_categorical_accuracy: 0.9904 - 245ms/epoch - 16ms/step
# Epoch 79/300
#
# Epoch 79: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1154 - sparse_categorical_accuracy: 0.9626 - val_loss: 0.0588 - val_sparse_categorical_accuracy: 0.9928 - 232ms/epoch - 15ms/step
# Epoch 80/300
#
# Epoch 80: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1233 - sparse_categorical_accuracy: 0.9626 - val_loss: 0.0546 - val_sparse_categorical_accuracy: 0.9928 - 244ms/epoch - 16ms/step
# Epoch 81/300
#
# Epoch 81: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0958 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.0495 - val_sparse_categorical_accuracy: 0.9904 - 236ms/epoch - 16ms/step
# Epoch 82/300
#
# Epoch 82: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1059 - sparse_categorical_accuracy: 0.9659 - val_loss: 0.0641 - val_sparse_categorical_accuracy: 0.9880 - 250ms/epoch - 17ms/step
# Epoch 83/300
#
# Epoch 83: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1276 - sparse_categorical_accuracy: 0.9593 - val_loss: 0.0670 - val_sparse_categorical_accuracy: 0.9880 - 234ms/epoch - 16ms/step
# Epoch 84/300
#
# Epoch 84: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1268 - sparse_categorical_accuracy: 0.9549 - val_loss: 0.0585 - val_sparse_categorical_accuracy: 0.9904 - 244ms/epoch - 16ms/step
# Epoch 85/300
#
# Epoch 85: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1196 - sparse_categorical_accuracy: 0.9659 - val_loss: 0.0589 - val_sparse_categorical_accuracy: 0.9928 - 238ms/epoch - 16ms/step
# Epoch 86/300
#
# Epoch 86: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1155 - sparse_categorical_accuracy: 0.9604 - val_loss: 0.0554 - val_sparse_categorical_accuracy: 0.9928 - 251ms/epoch - 17ms/step
# Epoch 87/300
#
# Epoch 87: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1282 - sparse_categorical_accuracy: 0.9516 - val_loss: 0.0590 - val_sparse_categorical_accuracy: 0.9880 - 243ms/epoch - 16ms/step
# Epoch 88/300
#
# Epoch 88: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1703 - sparse_categorical_accuracy: 0.9440 - val_loss: 0.0714 - val_sparse_categorical_accuracy: 0.9880 - 239ms/epoch - 16ms/step
# Epoch 89/300
#
# Epoch 89: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1668 - sparse_categorical_accuracy: 0.9407 - val_loss: 0.0563 - val_sparse_categorical_accuracy: 0.9904 - 241ms/epoch - 16ms/step
# Epoch 90/300
#
# Epoch 90: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1617 - sparse_categorical_accuracy: 0.9505 - val_loss: 0.0656 - val_sparse_categorical_accuracy: 0.9880 - 248ms/epoch - 17ms/step
# Epoch 91/300
#
# Epoch 91: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1575 - sparse_categorical_accuracy: 0.9593 - val_loss: 0.0647 - val_sparse_categorical_accuracy: 0.9856 - 250ms/epoch - 17ms/step
# Epoch 92/300
#
# Epoch 92: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1269 - sparse_categorical_accuracy: 0.9560 - val_loss: 0.0716 - val_sparse_categorical_accuracy: 0.9856 - 246ms/epoch - 16ms/step
# Epoch 93/300
#
# Epoch 93: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1289 - sparse_categorical_accuracy: 0.9582 - val_loss: 0.0718 - val_sparse_categorical_accuracy: 0.9880 - 238ms/epoch - 16ms/step
# Epoch 94/300
#
# Epoch 94: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1401 - sparse_categorical_accuracy: 0.9505 - val_loss: 0.0690 - val_sparse_categorical_accuracy: 0.9904 - 241ms/epoch - 16ms/step
# Epoch 95/300
#
# Epoch 95: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1153 - sparse_categorical_accuracy: 0.9604 - val_loss: 0.0660 - val_sparse_categorical_accuracy: 0.9928 - 248ms/epoch - 17ms/step
# Epoch 96/300
#
# Epoch 96: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1324 - sparse_categorical_accuracy: 0.9604 - val_loss: 0.0643 - val_sparse_categorical_accuracy: 0.9928 - 244ms/epoch - 16ms/step
# Epoch 97/300
#
# Epoch 97: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1228 - sparse_categorical_accuracy: 0.9593 - val_loss: 0.0631 - val_sparse_categorical_accuracy: 0.9928 - 240ms/epoch - 16ms/step
# Epoch 98/300
#
# Epoch 98: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1205 - sparse_categorical_accuracy: 0.9560 - val_loss: 0.0700 - val_sparse_categorical_accuracy: 0.9856 - 259ms/epoch - 17ms/step
# Epoch 99/300
#
# Epoch 99: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1229 - sparse_categorical_accuracy: 0.9637 - val_loss: 0.0626 - val_sparse_categorical_accuracy: 0.9856 - 249ms/epoch - 17ms/step
# Epoch 100/300
#
# Epoch 100: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1256 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.0637 - val_sparse_categorical_accuracy: 0.9880 - 244ms/epoch - 16ms/step
# Epoch 101/300
#
# Epoch 101: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1416 - sparse_categorical_accuracy: 0.9593 - val_loss: 0.0709 - val_sparse_categorical_accuracy: 0.9832 - 254ms/epoch - 17ms/step
# Epoch 102/300
#
# Epoch 102: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0945 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0744 - val_sparse_categorical_accuracy: 0.9856 - 251ms/epoch - 17ms/step
# Epoch 103/300
#
# Epoch 103: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1210 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.0736 - val_sparse_categorical_accuracy: 0.9856 - 270ms/epoch - 18ms/step
# Epoch 104/300
#
# Epoch 104: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1172 - sparse_categorical_accuracy: 0.9637 - val_loss: 0.0743 - val_sparse_categorical_accuracy: 0.9880 - 241ms/epoch - 16ms/step
# Epoch 105/300
#
# Epoch 105: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1128 - sparse_categorical_accuracy: 0.9582 - val_loss: 0.0792 - val_sparse_categorical_accuracy: 0.9904 - 255ms/epoch - 17ms/step
# Epoch 106/300
#
# Epoch 106: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1185 - sparse_categorical_accuracy: 0.9571 - val_loss: 0.0704 - val_sparse_categorical_accuracy: 0.9928 - 262ms/epoch - 17ms/step
# Epoch 107/300
#
# Epoch 107: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1208 - sparse_categorical_accuracy: 0.9560 - val_loss: 0.0781 - val_sparse_categorical_accuracy: 0.9904 - 262ms/epoch - 17ms/step
# Epoch 108/300
#
# Epoch 108: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1381 - sparse_categorical_accuracy: 0.9473 - val_loss: 0.0733 - val_sparse_categorical_accuracy: 0.9904 - 242ms/epoch - 16ms/step
# Epoch 109/300
#
# Epoch 109: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1375 - sparse_categorical_accuracy: 0.9527 - val_loss: 0.0689 - val_sparse_categorical_accuracy: 0.9904 - 239ms/epoch - 16ms/step
# Epoch 110/300
#
# Epoch 110: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1368 - sparse_categorical_accuracy: 0.9560 - val_loss: 0.0661 - val_sparse_categorical_accuracy: 0.9928 - 249ms/epoch - 17ms/step
# Epoch 111/300
#
# Epoch 111: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1409 - sparse_categorical_accuracy: 0.9516 - val_loss: 0.0648 - val_sparse_categorical_accuracy: 0.9904 - 256ms/epoch - 17ms/step
# Epoch 112/300
#
# Epoch 112: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0974 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0681 - val_sparse_categorical_accuracy: 0.9928 - 237ms/epoch - 16ms/step
# Epoch 113/300
#
# Epoch 113: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1249 - sparse_categorical_accuracy: 0.9626 - val_loss: 0.0720 - val_sparse_categorical_accuracy: 0.9904 - 245ms/epoch - 16ms/step
# Epoch 114/300
#
# Epoch 114: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1062 - sparse_categorical_accuracy: 0.9659 - val_loss: 0.0681 - val_sparse_categorical_accuracy: 0.9880 - 242ms/epoch - 16ms/step
# Epoch 115/300
#
# Epoch 115: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1111 - sparse_categorical_accuracy: 0.9604 - val_loss: 0.0667 - val_sparse_categorical_accuracy: 0.9904 - 241ms/epoch - 16ms/step
# Epoch 116/300
#
# Epoch 116: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1243 - sparse_categorical_accuracy: 0.9582 - val_loss: 0.0765 - val_sparse_categorical_accuracy: 0.9880 - 262ms/epoch - 17ms/step
# Epoch 117/300
#
# Epoch 117: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1175 - sparse_categorical_accuracy: 0.9571 - val_loss: 0.0853 - val_sparse_categorical_accuracy: 0.9808 - 240ms/epoch - 16ms/step
# Epoch 118/300
#
# Epoch 118: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1326 - sparse_categorical_accuracy: 0.9593 - val_loss: 0.0750 - val_sparse_categorical_accuracy: 0.9904 - 242ms/epoch - 16ms/step
# Epoch 119/300
#
# Epoch 119: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1079 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.0666 - val_sparse_categorical_accuracy: 0.9880 - 249ms/epoch - 17ms/step
# Epoch 120/300
#
# Epoch 120: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1097 - sparse_categorical_accuracy: 0.9681 - val_loss: 0.0646 - val_sparse_categorical_accuracy: 0.9904 - 243ms/epoch - 16ms/step
# Epoch 121/300
#
# Epoch 121: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0944 - sparse_categorical_accuracy: 0.9692 - val_loss: 0.0645 - val_sparse_categorical_accuracy: 0.9904 - 241ms/epoch - 16ms/step
# Epoch 122/300
#
# Epoch 122: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1176 - sparse_categorical_accuracy: 0.9692 - val_loss: 0.0608 - val_sparse_categorical_accuracy: 0.9904 - 240ms/epoch - 16ms/step
# Epoch 123/300
#
# Epoch 123: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0939 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.0662 - val_sparse_categorical_accuracy: 0.9904 - 252ms/epoch - 17ms/step
# Epoch 124/300
#
# Epoch 124: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1013 - sparse_categorical_accuracy: 0.9703 - val_loss: 0.0625 - val_sparse_categorical_accuracy: 0.9904 - 238ms/epoch - 16ms/step
# Epoch 125/300
#
# Epoch 125: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1209 - sparse_categorical_accuracy: 0.9626 - val_loss: 0.0733 - val_sparse_categorical_accuracy: 0.9904 - 235ms/epoch - 16ms/step
# Epoch 126/300
#
# Epoch 126: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0839 - sparse_categorical_accuracy: 0.9780 - val_loss: 0.0664 - val_sparse_categorical_accuracy: 0.9928 - 248ms/epoch - 17ms/step
# Epoch 127/300
#
# Epoch 127: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0755 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0634 - val_sparse_categorical_accuracy: 0.9928 - 242ms/epoch - 16ms/step
# Epoch 128/300
#
# Epoch 128: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0907 - sparse_categorical_accuracy: 0.9692 - val_loss: 0.0665 - val_sparse_categorical_accuracy: 0.9928 - 237ms/epoch - 16ms/step
# Epoch 129/300
#
# Epoch 129: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0936 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0642 - val_sparse_categorical_accuracy: 0.9928 - 234ms/epoch - 16ms/step
# Epoch 130/300
#
# Epoch 130: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0771 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0692 - val_sparse_categorical_accuracy: 0.9904 - 243ms/epoch - 16ms/step
# Epoch 131/300
#
# Epoch 131: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0878 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.0748 - val_sparse_categorical_accuracy: 0.9880 - 253ms/epoch - 17ms/step
# Epoch 132/300
#
# Epoch 132: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0949 - sparse_categorical_accuracy: 0.9681 - val_loss: 0.0660 - val_sparse_categorical_accuracy: 0.9928 - 242ms/epoch - 16ms/step
# Epoch 133/300
#
# Epoch 133: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0907 - sparse_categorical_accuracy: 0.9703 - val_loss: 0.0692 - val_sparse_categorical_accuracy: 0.9928 - 241ms/epoch - 16ms/step
# Epoch 134/300
#
# Epoch 134: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0875 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0678 - val_sparse_categorical_accuracy: 0.9928 - 241ms/epoch - 16ms/step
# Epoch 135/300
#
# Epoch 135: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0904 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.0694 - val_sparse_categorical_accuracy: 0.9928 - 247ms/epoch - 16ms/step
# Epoch 136/300
#
# Epoch 136: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0847 - sparse_categorical_accuracy: 0.9703 - val_loss: 0.0714 - val_sparse_categorical_accuracy: 0.9904 - 249ms/epoch - 17ms/step
# Epoch 137/300
#
# Epoch 137: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0907 - sparse_categorical_accuracy: 0.9692 - val_loss: 0.0673 - val_sparse_categorical_accuracy: 0.9904 - 240ms/epoch - 16ms/step
# Epoch 138/300
#
# Epoch 138: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0787 - sparse_categorical_accuracy: 0.9791 - val_loss: 0.0743 - val_sparse_categorical_accuracy: 0.9904 - 247ms/epoch - 16ms/step
# Epoch 139/300
#
# Epoch 139: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0853 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.0735 - val_sparse_categorical_accuracy: 0.9928 - 243ms/epoch - 16ms/step
# Epoch 140/300
#
# Epoch 140: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0889 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0691 - val_sparse_categorical_accuracy: 0.9904 - 239ms/epoch - 16ms/step
# Epoch 141/300
#
# Epoch 141: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0899 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0698 - val_sparse_categorical_accuracy: 0.9880 - 243ms/epoch - 16ms/step
# Epoch 142/300
#
# Epoch 142: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1019 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0737 - val_sparse_categorical_accuracy: 0.9904 - 244ms/epoch - 16ms/step
# Epoch 143/300
#
# Epoch 143: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0825 - sparse_categorical_accuracy: 0.9791 - val_loss: 0.0673 - val_sparse_categorical_accuracy: 0.9880 - 253ms/epoch - 17ms/step
# Epoch 144/300
#
# Epoch 144: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0812 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0643 - val_sparse_categorical_accuracy: 0.9904 - 236ms/epoch - 16ms/step
# Epoch 145/300
#
# Epoch 145: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0959 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.0662 - val_sparse_categorical_accuracy: 0.9904 - 238ms/epoch - 16ms/step
# Epoch 146/300
#
# Epoch 146: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0726 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.0752 - val_sparse_categorical_accuracy: 0.9880 - 247ms/epoch - 16ms/step
# Epoch 147/300
#
# Epoch 147: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1157 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0716 - val_sparse_categorical_accuracy: 0.9880 - 249ms/epoch - 17ms/step
# Epoch 148/300
#
# Epoch 148: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0839 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.0703 - val_sparse_categorical_accuracy: 0.9880 - 240ms/epoch - 16ms/step
# Epoch 149/300
#
# Epoch 149: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1009 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0671 - val_sparse_categorical_accuracy: 0.9904 - 233ms/epoch - 16ms/step
# Epoch 150/300
#
# Epoch 150: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0922 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0742 - val_sparse_categorical_accuracy: 0.9880 - 251ms/epoch - 17ms/step
# Epoch 151/300
#
# Epoch 151: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1002 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.0674 - val_sparse_categorical_accuracy: 0.9880 - 240ms/epoch - 16ms/step
# Epoch 152/300
#
# Epoch 152: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0907 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0620 - val_sparse_categorical_accuracy: 0.9904 - 247ms/epoch - 16ms/step
# Epoch 153/300
#
# Epoch 153: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0842 - sparse_categorical_accuracy: 0.9703 - val_loss: 0.0716 - val_sparse_categorical_accuracy: 0.9880 - 235ms/epoch - 16ms/step
# Epoch 154/300
#
# Epoch 154: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0754 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.0704 - val_sparse_categorical_accuracy: 0.9904 - 240ms/epoch - 16ms/step
# Epoch 155/300
#
# Epoch 155: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0813 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.0657 - val_sparse_categorical_accuracy: 0.9928 - 246ms/epoch - 16ms/step
# Epoch 156/300
#
# Epoch 156: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0814 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.0736 - val_sparse_categorical_accuracy: 0.9904 - 243ms/epoch - 16ms/step
# Epoch 157/300
#
# Epoch 157: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0901 - sparse_categorical_accuracy: 0.9703 - val_loss: 0.0670 - val_sparse_categorical_accuracy: 0.9904 - 236ms/epoch - 16ms/step
# Epoch 158/300
#
# Epoch 158: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1103 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.0737 - val_sparse_categorical_accuracy: 0.9856 - 238ms/epoch - 16ms/step
# Epoch 159/300
#
# Epoch 159: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1071 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.0725 - val_sparse_categorical_accuracy: 0.9880 - 265ms/epoch - 18ms/step
# Epoch 160/300
#
# Epoch 160: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0976 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0602 - val_sparse_categorical_accuracy: 0.9904 - 245ms/epoch - 16ms/step
# Epoch 161/300
#
# Epoch 161: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0966 - sparse_categorical_accuracy: 0.9648 - val_loss: 0.0666 - val_sparse_categorical_accuracy: 0.9904 - 238ms/epoch - 16ms/step
# Epoch 162/300
#
# Epoch 162: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1053 - sparse_categorical_accuracy: 0.9681 - val_loss: 0.0681 - val_sparse_categorical_accuracy: 0.9904 - 237ms/epoch - 16ms/step
# Epoch 163/300
#
# Epoch 163: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0921 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0636 - val_sparse_categorical_accuracy: 0.9904 - 235ms/epoch - 16ms/step
# Epoch 164/300
#
# Epoch 164: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0716 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.0690 - val_sparse_categorical_accuracy: 0.9880 - 251ms/epoch - 17ms/step
# Epoch 165/300
#
# Epoch 165: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0727 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.0713 - val_sparse_categorical_accuracy: 0.9880 - 249ms/epoch - 17ms/step
# Epoch 166/300
#
# Epoch 166: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0602 - sparse_categorical_accuracy: 0.9846 - val_loss: 0.0698 - val_sparse_categorical_accuracy: 0.9904 - 246ms/epoch - 16ms/step
# Epoch 167/300
#
# Epoch 167: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0556 - sparse_categorical_accuracy: 0.9890 - val_loss: 0.0766 - val_sparse_categorical_accuracy: 0.9856 - 240ms/epoch - 16ms/step
# Epoch 168/300
#
# Epoch 168: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0799 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0695 - val_sparse_categorical_accuracy: 0.9928 - 245ms/epoch - 16ms/step
# Epoch 169/300
#
# Epoch 169: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0937 - sparse_categorical_accuracy: 0.9637 - val_loss: 0.0709 - val_sparse_categorical_accuracy: 0.9880 - 240ms/epoch - 16ms/step
# Epoch 170/300
#
# Epoch 170: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0900 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.0754 - val_sparse_categorical_accuracy: 0.9880 - 239ms/epoch - 16ms/step
# Epoch 171/300
#
# Epoch 171: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1093 - sparse_categorical_accuracy: 0.9637 - val_loss: 0.0667 - val_sparse_categorical_accuracy: 0.9928 - 256ms/epoch - 17ms/step
# Epoch 172/300
#
# Epoch 172: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1043 - sparse_categorical_accuracy: 0.9637 - val_loss: 0.0681 - val_sparse_categorical_accuracy: 0.9928 - 263ms/epoch - 18ms/step
# Epoch 173/300
#
# Epoch 173: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0839 - sparse_categorical_accuracy: 0.9703 - val_loss: 0.0670 - val_sparse_categorical_accuracy: 0.9904 - 237ms/epoch - 16ms/step
# Epoch 174/300
#
# Epoch 174: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0827 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0664 - val_sparse_categorical_accuracy: 0.9856 - 250ms/epoch - 17ms/step
# Epoch 175/300
#
# Epoch 175: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0851 - sparse_categorical_accuracy: 0.9813 - val_loss: 0.0655 - val_sparse_categorical_accuracy: 0.9856 - 240ms/epoch - 16ms/step
# Epoch 176/300
#
# Epoch 176: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0871 - sparse_categorical_accuracy: 0.9692 - val_loss: 0.0636 - val_sparse_categorical_accuracy: 0.9904 - 264ms/epoch - 18ms/step
# Epoch 177/300
#
# Epoch 177: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1088 - sparse_categorical_accuracy: 0.9659 - val_loss: 0.0639 - val_sparse_categorical_accuracy: 0.9904 - 240ms/epoch - 16ms/step
# Epoch 178/300
#
# Epoch 178: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0847 - sparse_categorical_accuracy: 0.9780 - val_loss: 0.0681 - val_sparse_categorical_accuracy: 0.9904 - 246ms/epoch - 16ms/step
# Epoch 179/300
#
# Epoch 179: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0931 - sparse_categorical_accuracy: 0.9703 - val_loss: 0.0644 - val_sparse_categorical_accuracy: 0.9904 - 250ms/epoch - 17ms/step
# Epoch 180/300
#
# Epoch 180: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0835 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.0690 - val_sparse_categorical_accuracy: 0.9904 - 248ms/epoch - 17ms/step
# Epoch 181/300
#
# Epoch 181: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0947 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.0709 - val_sparse_categorical_accuracy: 0.9856 - 247ms/epoch - 16ms/step
# Epoch 182/300
#
# Epoch 182: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1272 - sparse_categorical_accuracy: 0.9604 - val_loss: 0.0802 - val_sparse_categorical_accuracy: 0.9880 - 246ms/epoch - 16ms/step
# Epoch 183/300
#
# Epoch 183: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1104 - sparse_categorical_accuracy: 0.9681 - val_loss: 0.0673 - val_sparse_categorical_accuracy: 0.9928 - 240ms/epoch - 16ms/step
# Epoch 184/300
#
# Epoch 184: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0739 - sparse_categorical_accuracy: 0.9835 - val_loss: 0.0702 - val_sparse_categorical_accuracy: 0.9880 - 242ms/epoch - 16ms/step
# Epoch 185/300
#
# Epoch 185: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0832 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.0710 - val_sparse_categorical_accuracy: 0.9880 - 250ms/epoch - 17ms/step
# Epoch 186/300
#
# Epoch 186: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0776 - sparse_categorical_accuracy: 0.9780 - val_loss: 0.0698 - val_sparse_categorical_accuracy: 0.9904 - 242ms/epoch - 16ms/step
# Epoch 187/300
#
# Epoch 187: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0734 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.0702 - val_sparse_categorical_accuracy: 0.9880 - 233ms/epoch - 16ms/step
# Epoch 188/300
#
# Epoch 188: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1106 - sparse_categorical_accuracy: 0.9681 - val_loss: 0.0692 - val_sparse_categorical_accuracy: 0.9904 - 255ms/epoch - 17ms/step
# Epoch 189/300
#
# Epoch 189: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0836 - sparse_categorical_accuracy: 0.9681 - val_loss: 0.0682 - val_sparse_categorical_accuracy: 0.9904 - 253ms/epoch - 17ms/step
# Epoch 190/300
#
# Epoch 190: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0931 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0663 - val_sparse_categorical_accuracy: 0.9928 - 257ms/epoch - 17ms/step
# Epoch 191/300
#
# Epoch 191: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0826 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0651 - val_sparse_categorical_accuracy: 0.9904 - 253ms/epoch - 17ms/step
# Epoch 192/300
#
# Epoch 192: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1005 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.0608 - val_sparse_categorical_accuracy: 0.9928 - 249ms/epoch - 17ms/step
# Epoch 193/300
#
# Epoch 193: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0816 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0596 - val_sparse_categorical_accuracy: 0.9904 - 253ms/epoch - 17ms/step
# Epoch 194/300
#
# Epoch 194: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0926 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.0615 - val_sparse_categorical_accuracy: 0.9904 - 252ms/epoch - 17ms/step
# Epoch 195/300
#
# Epoch 195: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1138 - sparse_categorical_accuracy: 0.9692 - val_loss: 0.0625 - val_sparse_categorical_accuracy: 0.9904 - 244ms/epoch - 16ms/step
# Epoch 196/300
#
# Epoch 196: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1036 - sparse_categorical_accuracy: 0.9659 - val_loss: 0.0659 - val_sparse_categorical_accuracy: 0.9880 - 458ms/epoch - 31ms/step
# Epoch 197/300
#
# Epoch 197: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0988 - sparse_categorical_accuracy: 0.9703 - val_loss: 0.0630 - val_sparse_categorical_accuracy: 0.9904 - 273ms/epoch - 18ms/step
# Epoch 198/300
#
# Epoch 198: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0849 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0671 - val_sparse_categorical_accuracy: 0.9904 - 245ms/epoch - 16ms/step
# Epoch 199/300
#
# Epoch 199: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 1s - loss: 0.0826 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0706 - val_sparse_categorical_accuracy: 0.9880 - 535ms/epoch - 36ms/step
# Epoch 200/300
#
# Epoch 200: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0847 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.0721 - val_sparse_categorical_accuracy: 0.9880 - 244ms/epoch - 16ms/step
# Epoch 201/300
#
# Epoch 201: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0783 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.0741 - val_sparse_categorical_accuracy: 0.9880 - 237ms/epoch - 16ms/step
# Epoch 202/300
#
# Epoch 202: val_sparse_categorical_accuracy did not improve from 0.99279
# ...
# Epoch 234/300
#
# Epoch 234: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0975 - sparse_categorical_accuracy: 0.9692 - val_loss: 0.0805 - val_sparse_categorical_accuracy: 0.9856 - 239ms/epoch - 16ms/step
# Epoch 235/300
#
# Epoch 235: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0923 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0724 - val_sparse_categorical_accuracy: 0.9880 - 243ms/epoch - 16ms/step
# Epoch 236/300
#
# Epoch 236: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0664 - sparse_categorical_accuracy: 0.9835 - val_loss: 0.0678 - val_sparse_categorical_accuracy: 0.9904 - 234ms/epoch - 16ms/step
# Epoch 237/300
#
# Epoch 237: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0794 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0798 - val_sparse_categorical_accuracy: 0.9856 - 248ms/epoch - 17ms/step
# Epoch 238/300
#
# Epoch 238: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0988 - sparse_categorical_accuracy: 0.9681 - val_loss: 0.0790 - val_sparse_categorical_accuracy: 0.9880 - 235ms/epoch - 16ms/step
# Epoch 239/300
#
# Epoch 239: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0801 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0738 - val_sparse_categorical_accuracy: 0.9856 - 256ms/epoch - 17ms/step
# Epoch 240/300
#
# Epoch 240: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0638 - sparse_categorical_accuracy: 0.9791 - val_loss: 0.0782 - val_sparse_categorical_accuracy: 0.9880 - 252ms/epoch - 17ms/step
# Epoch 241/300
#
# Epoch 241: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0697 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.0769 - val_sparse_categorical_accuracy: 0.9856 - 256ms/epoch - 17ms/step
# Epoch 242/300
#
# Epoch 242: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0729 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0798 - val_sparse_categorical_accuracy: 0.9832 - 240ms/epoch - 16ms/step
# Epoch 243/300
#
# Epoch 243: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0877 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0766 - val_sparse_categorical_accuracy: 0.9856 - 254ms/epoch - 17ms/step
# Epoch 244/300
#
# Epoch 244: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0791 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0793 - val_sparse_categorical_accuracy: 0.9856 - 241ms/epoch - 16ms/step
# Epoch 245/300
#
# Epoch 245: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0710 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.0790 - val_sparse_categorical_accuracy: 0.9880 - 258ms/epoch - 17ms/step
# Epoch 246/300
#
# Epoch 246: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0731 - sparse_categorical_accuracy: 0.9769 - val_loss: 0.0791 - val_sparse_categorical_accuracy: 0.9880 - 249ms/epoch - 17ms/step
# Epoch 247/300
#
# Epoch 247: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0828 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.0738 - val_sparse_categorical_accuracy: 0.9880 - 246ms/epoch - 16ms/step
# Epoch 248/300
#
# Epoch 248: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0830 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0853 - val_sparse_categorical_accuracy: 0.9880 - 241ms/epoch - 16ms/step
# Epoch 249/300
#
# Epoch 249: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0993 - sparse_categorical_accuracy: 0.9648 - val_loss: 0.0902 - val_sparse_categorical_accuracy: 0.9856 - 250ms/epoch - 17ms/step
# Epoch 250/300
#
# Epoch 250: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1057 - sparse_categorical_accuracy: 0.9648 - val_loss: 0.0837 - val_sparse_categorical_accuracy: 0.9880 - 244ms/epoch - 16ms/step
# Epoch 251/300
#
# Epoch 251: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1047 - sparse_categorical_accuracy: 0.9615 - val_loss: 0.0828 - val_sparse_categorical_accuracy: 0.9880 - 243ms/epoch - 16ms/step
# Epoch 252/300
#
# Epoch 252: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0938 - sparse_categorical_accuracy: 0.9637 - val_loss: 0.0775 - val_sparse_categorical_accuracy: 0.9904 - 243ms/epoch - 16ms/step
# Epoch 253/300
#
# Epoch 253: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0758 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.0750 - val_sparse_categorical_accuracy: 0.9904 - 246ms/epoch - 16ms/step
# Epoch 254/300
#
# Epoch 254: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0789 - sparse_categorical_accuracy: 0.9692 - val_loss: 0.0851 - val_sparse_categorical_accuracy: 0.9904 - 257ms/epoch - 17ms/step
# Epoch 255/300
#
# Epoch 255: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0761 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.0772 - val_sparse_categorical_accuracy: 0.9904 - 239ms/epoch - 16ms/step
# Epoch 256/300
#
# Epoch 256: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0755 - sparse_categorical_accuracy: 0.9769 - val_loss: 0.0766 - val_sparse_categorical_accuracy: 0.9880 - 233ms/epoch - 16ms/step
# Epoch 257/300
#
# Epoch 257: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0574 - sparse_categorical_accuracy: 0.9846 - val_loss: 0.0746 - val_sparse_categorical_accuracy: 0.9904 - 252ms/epoch - 17ms/step
# Epoch 258/300
#
# Epoch 258: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0496 - sparse_categorical_accuracy: 0.9868 - val_loss: 0.0749 - val_sparse_categorical_accuracy: 0.9904 - 243ms/epoch - 16ms/step
# Epoch 259/300
#
# Epoch 259: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0910 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0709 - val_sparse_categorical_accuracy: 0.9880 - 250ms/epoch - 17ms/step
# Epoch 260/300
#
# Epoch 260: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0856 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.0762 - val_sparse_categorical_accuracy: 0.9880 - 237ms/epoch - 16ms/step
# Epoch 261/300
#
# Epoch 261: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1030 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.0786 - val_sparse_categorical_accuracy: 0.9904 - 251ms/epoch - 17ms/step
# Epoch 262/300
#
# Epoch 262: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0862 - sparse_categorical_accuracy: 0.9692 - val_loss: 0.0754 - val_sparse_categorical_accuracy: 0.9904 - 243ms/epoch - 16ms/step
# Epoch 263/300
#
# Epoch 263: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0666 - sparse_categorical_accuracy: 0.9780 - val_loss: 0.0677 - val_sparse_categorical_accuracy: 0.9880 - 251ms/epoch - 17ms/step
# Epoch 264/300
#
# Epoch 264: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1103 - sparse_categorical_accuracy: 0.9648 - val_loss: 0.0749 - val_sparse_categorical_accuracy: 0.9880 - 243ms/epoch - 16ms/step
# Epoch 265/300
#
# Epoch 265: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0932 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0722 - val_sparse_categorical_accuracy: 0.9904 - 250ms/epoch - 17ms/step
# Epoch 266/300
#
# Epoch 266: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1107 - sparse_categorical_accuracy: 0.9692 - val_loss: 0.0876 - val_sparse_categorical_accuracy: 0.9880 - 241ms/epoch - 16ms/step
# Epoch 267/300
#
# Epoch 267: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0832 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.0823 - val_sparse_categorical_accuracy: 0.9904 - 244ms/epoch - 16ms/step
# Epoch 268/300
#
# Epoch 268: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0861 - sparse_categorical_accuracy: 0.9681 - val_loss: 0.0692 - val_sparse_categorical_accuracy: 0.9904 - 228ms/epoch - 15ms/step
# Epoch 269/300
#
# Epoch 269: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0837 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0709 - val_sparse_categorical_accuracy: 0.9928 - 253ms/epoch - 17ms/step
# Epoch 270/300
#
# Epoch 270: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0740 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0736 - val_sparse_categorical_accuracy: 0.9904 - 232ms/epoch - 15ms/step
# Epoch 271/300
#
# Epoch 271: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0793 - sparse_categorical_accuracy: 0.9692 - val_loss: 0.0820 - val_sparse_categorical_accuracy: 0.9856 - 252ms/epoch - 17ms/step
# Epoch 272/300
#
# Epoch 272: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0766 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.0745 - val_sparse_categorical_accuracy: 0.9928 - 242ms/epoch - 16ms/step
# Epoch 273/300
#
# Epoch 273: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0687 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0771 - val_sparse_categorical_accuracy: 0.9904 - 244ms/epoch - 16ms/step
# Epoch 274/300
#
# Epoch 274: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0776 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0889 - val_sparse_categorical_accuracy: 0.9856 - 241ms/epoch - 16ms/step
# Epoch 275/300
#
# Epoch 275: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0735 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0852 - val_sparse_categorical_accuracy: 0.9856 - 241ms/epoch - 16ms/step
# Epoch 276/300
#
# Epoch 276: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0533 - sparse_categorical_accuracy: 0.9846 - val_loss: 0.0863 - val_sparse_categorical_accuracy: 0.9880 - 248ms/epoch - 17ms/step
# Epoch 277/300
#
# Epoch 277: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0715 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0967 - val_sparse_categorical_accuracy: 0.9880 - 243ms/epoch - 16ms/step
# Epoch 278/300
#
# Epoch 278: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0708 - sparse_categorical_accuracy: 0.9780 - val_loss: 0.0892 - val_sparse_categorical_accuracy: 0.9904 - 245ms/epoch - 16ms/step
# Epoch 279/300
#
# Epoch 279: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0731 - sparse_categorical_accuracy: 0.9780 - val_loss: 0.0848 - val_sparse_categorical_accuracy: 0.9904 - 244ms/epoch - 16ms/step
# Epoch 280/300
#
# Epoch 280: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0938 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.0839 - val_sparse_categorical_accuracy: 0.9904 - 242ms/epoch - 16ms/step
# Epoch 281/300
#
# Epoch 281: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0664 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0802 - val_sparse_categorical_accuracy: 0.9904 - 252ms/epoch - 17ms/step
# Epoch 282/300
#
# Epoch 282: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0758 - sparse_categorical_accuracy: 0.9780 - val_loss: 0.0729 - val_sparse_categorical_accuracy: 0.9904 - 254ms/epoch - 17ms/step
# Epoch 283/300
#
# Epoch 283: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0916 - sparse_categorical_accuracy: 0.9703 - val_loss: 0.0641 - val_sparse_categorical_accuracy: 0.9928 - 247ms/epoch - 16ms/step
# Epoch 284/300
#
# Epoch 284: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0818 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.0601 - val_sparse_categorical_accuracy: 0.9928 - 253ms/epoch - 17ms/step
# Epoch 285/300
#
# Epoch 285: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1038 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.0684 - val_sparse_categorical_accuracy: 0.9928 - 249ms/epoch - 17ms/step
# Epoch 286/300
#
# Epoch 286: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0737 - sparse_categorical_accuracy: 0.9769 - val_loss: 0.0670 - val_sparse_categorical_accuracy: 0.9880 - 239ms/epoch - 16ms/step
# Epoch 287/300
#
# Epoch 287: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0725 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.0688 - val_sparse_categorical_accuracy: 0.9904 - 248ms/epoch - 17ms/step
# Epoch 288/300
#
# Epoch 288: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0777 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0753 - val_sparse_categorical_accuracy: 0.9904 - 243ms/epoch - 16ms/step
# Epoch 289/300
#
# Epoch 289: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.1040 - sparse_categorical_accuracy: 0.9692 - val_loss: 0.0750 - val_sparse_categorical_accuracy: 0.9904 - 260ms/epoch - 17ms/step
# Epoch 290/300
#
# Epoch 290: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0826 - sparse_categorical_accuracy: 0.9703 - val_loss: 0.0709 - val_sparse_categorical_accuracy: 0.9904 - 248ms/epoch - 17ms/step
# Epoch 291/300
#
# Epoch 291: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0678 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.0661 - val_sparse_categorical_accuracy: 0.9904 - 242ms/epoch - 16ms/step
# Epoch 292/300
#
# Epoch 292: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0740 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0811 - val_sparse_categorical_accuracy: 0.9880 - 249ms/epoch - 17ms/step
# Epoch 293/300
#
# Epoch 293: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0636 - sparse_categorical_accuracy: 0.9835 - val_loss: 0.0840 - val_sparse_categorical_accuracy: 0.9880 - 244ms/epoch - 16ms/step
# Epoch 294/300
#
# Epoch 294: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0825 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0799 - val_sparse_categorical_accuracy: 0.9904 - 244ms/epoch - 16ms/step
# Epoch 295/300
#
# Epoch 295: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0781 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0742 - val_sparse_categorical_accuracy: 0.9904 - 244ms/epoch - 16ms/step
# Epoch 296/300
#
# Epoch 296: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0939 - sparse_categorical_accuracy: 0.9692 - val_loss: 0.0727 - val_sparse_categorical_accuracy: 0.9904 - 237ms/epoch - 16ms/step
# Epoch 297/300
#
# Epoch 297: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0913 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.0727 - val_sparse_categorical_accuracy: 0.9856 - 255ms/epoch - 17ms/step
# Epoch 298/300
#
# Epoch 298: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0719 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.0695 - val_sparse_categorical_accuracy: 0.9856 - 243ms/epoch - 16ms/step
# Epoch 299/300
#
# Epoch 299: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0703 - sparse_categorical_accuracy: 0.9813 - val_loss: 0.0678 - val_sparse_categorical_accuracy: 0.9880 - 244ms/epoch - 16ms/step
# Epoch 300/300
#
# Epoch 300: val_sparse_categorical_accuracy did not improve from 0.99279
# 15/15 - 0s - loss: 0.0936 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.0661 - val_sparse_categorical_accuracy: 0.9904 - 237ms/epoch - 16ms/step
# 86.43291021300001 seconds

# %%
class Distiller(keras.Model):
    def __init__(self, student, teacher):
        super(Distiller, self).__init__()
        self.teacher = teacher
        self.student = student

    def compile(
        self,
        optimizer,
        metrics,
        student_loss_fn,
        distillation_loss_fn,
        alpha=0.1,
        temperature=10,
    ):
        """ Configure the distiller.

        Args:
            optimizer: Keras optimizer for the student weights
            metrics: Keras metrics for evaluation
            student_loss_fn: Loss function of difference between student
                predictions and ground-truth
            distillation_loss_fn: Loss function of difference between soft
                student predictions and soft teacher predictions
            alpha: weight to student_loss_fn and 1-alpha to distillation_loss_fn
            temperature: Temperature for softening probability distributions.
                Larger temperature gives softer distributions.
        """
        super(Distiller, self).compile(optimizer=optimizer, metrics=metrics)
        self.student_loss_fn = student_loss_fn
        self.distillation_loss_fn = distillation_loss_fn
        self.alpha = alpha
        self.temperature = temperature

    def train_step(self, data):
        # Unpack data
        x, y = data

        # Forward pass of teacher
        teacher_predictions = self.teacher(x, training=False)

        with tf.GradientTape() as tape:
            # Forward pass of student
            student_predictions = self.student(x, training=True)

            # Compute losses
            student_loss = self.student_loss_fn(y, student_predictions)

            # Compute scaled distillation loss from https://arxiv.org/abs/1503.02531
            # The magnitudes of the gradients produced by the soft targets scale
            # as 1/T^2, multiply them by T^2 when using both hard and soft targets.
            distillation_loss = (
                self.distillation_loss_fn(
                    tf.nn.softmax(teacher_predictions / self.temperature, axis=1),
                    tf.nn.softmax(student_predictions / self.temperature, axis=1),
                )
                * self.temperature**2
            )

            loss = self.alpha * student_loss + (1 - self.alpha) * distillation_loss

        # Compute gradients
        trainable_vars = self.student.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)

        # Update weights
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))

        # Update the metrics configured in `compile()`.
        self.compiled_metrics.update_state(y, student_predictions)

        # Return a dict of performance
        results = {m.name: m.result() for m in self.metrics}
        results.update(
            {"student_loss": student_loss, "distillation_loss": distillation_loss}
        )
        return results

    def test_step(self, data):
        # Unpack the data
        x, y = data

        # Compute predictions
        y_prediction = self.student(x, training=False)

        # Calculate the loss
        student_loss = self.student_loss_fn(y, y_prediction)

        # Update the metrics.
        self.compiled_metrics.update_state(y, y_prediction)

        # Return a dict of performance
        results = {m.name: m.result() for m in self.metrics}
        results.update({"student_loss": student_loss})
        return results

# %%
#Train student as does usually
student.compile(loss=tensorflow.keras.losses.sparse_categorical_crossentropy,
              optimizer=tensorflow.keras.optimizers.Adam(),
              metrics=[keras.metrics.SparseCategoricalAccuracy()])

student.save("student.h5")
teacher.save("teacher.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
# Initialize and compile distiller
distiller = Distiller(student=student, teacher=teacher)
distiller.compile(
    optimizer=tensorflow.keras.optimizers.Adam(),
    metrics=[keras.metrics.SparseCategoricalAccuracy()],
    student_loss_fn=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    distillation_loss_fn=keras.losses.KLDivergence(),
    alpha=0.1,
    temperature=10,
)

historyt = distiller.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=50, batch_size=64, verbose=2)

historys =  distiller.evaluate(x_test, y_test, batch_size=64, verbose=2)

hist_df = pd.DataFrame(historyt.history)

hist_csv_file = '15000historyBiLSTM33.csv'
with open(hist_csv_file, mode='w') as f:
    		hist_df.to_csv(f)
# Out:
# Epoch 1/50
# 15/15 - 5s - sparse_categorical_accuracy: 0.2780 - student_loss: 1.1370 - distillation_loss: 0.1348 - val_sparse_categorical_accuracy: 0.3894 - val_student_loss: 1.2897 - 5s/epoch - 317ms/step
# Epoch 2/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.4121 - student_loss: 1.0557 - distillation_loss: 0.1050 - val_sparse_categorical_accuracy: 0.6659 - val_student_loss: 1.2321 - 276ms/epoch - 18ms/step
# Epoch 3/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.4890 - student_loss: 1.0954 - distillation_loss: 0.1317 - val_sparse_categorical_accuracy: 0.8774 - val_student_loss: 1.0988 - 299ms/epoch - 20ms/step
# Epoch 4/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.5341 - student_loss: 0.9714 - distillation_loss: 0.0748 - val_sparse_categorical_accuracy: 0.9279 - val_student_loss: 1.0702 - 281ms/epoch - 19ms/step
# Epoch 5/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.5681 - student_loss: 0.9994 - distillation_loss: 0.0984 - val_sparse_categorical_accuracy: 0.9736 - val_student_loss: 1.0282 - 279ms/epoch - 19ms/step
# Epoch 6/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.6088 - student_loss: 1.0899 - distillation_loss: 0.1311 - val_sparse_categorical_accuracy: 0.9567 - val_student_loss: 1.0197 - 273ms/epoch - 18ms/step
# Epoch 7/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.6571 - student_loss: 1.0029 - distillation_loss: 0.0785 - val_sparse_categorical_accuracy: 0.9591 - val_student_loss: 1.0058 - 272ms/epoch - 18ms/step
# Epoch 8/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.6703 - student_loss: 0.9712 - distillation_loss: 0.0779 - val_sparse_categorical_accuracy: 0.9712 - val_student_loss: 0.9751 - 275ms/epoch - 18ms/step
# Epoch 9/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.7110 - student_loss: 1.0210 - distillation_loss: 0.0813 - val_sparse_categorical_accuracy: 0.9639 - val_student_loss: 0.9636 - 274ms/epoch - 18ms/step
# Epoch 10/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.7352 - student_loss: 0.8956 - distillation_loss: 0.0594 - val_sparse_categorical_accuracy: 0.9760 - val_student_loss: 0.9294 - 282ms/epoch - 19ms/step
# Epoch 11/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.7604 - student_loss: 1.0065 - distillation_loss: 0.0758 - val_sparse_categorical_accuracy: 0.9736 - val_student_loss: 0.9398 - 269ms/epoch - 18ms/step
# Epoch 12/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.7637 - student_loss: 0.9699 - distillation_loss: 0.0648 - val_sparse_categorical_accuracy: 0.9760 - val_student_loss: 0.9367 - 268ms/epoch - 18ms/step
# Epoch 13/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.7670 - student_loss: 0.8293 - distillation_loss: 0.0569 - val_sparse_categorical_accuracy: 0.9639 - val_student_loss: 0.9186 - 266ms/epoch - 18ms/step
# Epoch 14/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.7747 - student_loss: 0.9014 - distillation_loss: 0.0489 - val_sparse_categorical_accuracy: 0.9784 - val_student_loss: 0.9568 - 278ms/epoch - 19ms/step
# Epoch 15/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.7791 - student_loss: 1.0647 - distillation_loss: 0.0626 - val_sparse_categorical_accuracy: 0.9808 - val_student_loss: 0.9356 - 270ms/epoch - 18ms/step
# Epoch 16/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.8110 - student_loss: 0.8418 - distillation_loss: 0.0580 - val_sparse_categorical_accuracy: 0.9856 - val_student_loss: 0.9191 - 263ms/epoch - 18ms/step
# Epoch 17/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.8132 - student_loss: 0.9465 - distillation_loss: 0.0355 - val_sparse_categorical_accuracy: 0.9808 - val_student_loss: 0.9314 - 266ms/epoch - 18ms/step
# Epoch 18/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.8209 - student_loss: 0.9503 - distillation_loss: 0.0564 - val_sparse_categorical_accuracy: 0.9856 - val_student_loss: 0.8720 - 296ms/epoch - 20ms/step
# Epoch 19/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.8505 - student_loss: 0.9378 - distillation_loss: 0.0495 - val_sparse_categorical_accuracy: 0.9880 - val_student_loss: 0.8654 - 277ms/epoch - 18ms/step
# Epoch 20/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.8527 - student_loss: 0.8919 - distillation_loss: 0.0455 - val_sparse_categorical_accuracy: 0.9880 - val_student_loss: 0.8692 - 285ms/epoch - 19ms/step
# Epoch 21/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.8637 - student_loss: 0.9261 - distillation_loss: 0.0474 - val_sparse_categorical_accuracy: 0.9856 - val_student_loss: 0.9010 - 273ms/epoch - 18ms/step
# Epoch 22/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.8725 - student_loss: 0.8785 - distillation_loss: 0.0478 - val_sparse_categorical_accuracy: 0.9856 - val_student_loss: 0.8955 - 279ms/epoch - 19ms/step
# Epoch 23/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.8725 - student_loss: 0.9204 - distillation_loss: 0.0452 - val_sparse_categorical_accuracy: 0.9856 - val_student_loss: 0.8937 - 261ms/epoch - 17ms/step
# Epoch 24/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9055 - student_loss: 0.9303 - distillation_loss: 0.0616 - val_sparse_categorical_accuracy: 0.9880 - val_student_loss: 0.8634 - 267ms/epoch - 18ms/step
# Epoch 25/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.8879 - student_loss: 0.9217 - distillation_loss: 0.0398 - val_sparse_categorical_accuracy: 0.9856 - val_student_loss: 0.8913 - 277ms/epoch - 18ms/step
# Epoch 26/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9044 - student_loss: 0.8457 - distillation_loss: 0.0332 - val_sparse_categorical_accuracy: 0.9856 - val_student_loss: 0.8904 - 280ms/epoch - 19ms/step
# Epoch 27/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.8956 - student_loss: 0.9493 - distillation_loss: 0.0531 - val_sparse_categorical_accuracy: 0.9856 - val_student_loss: 0.8765 - 266ms/epoch - 18ms/step
# Epoch 28/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9154 - student_loss: 0.8875 - distillation_loss: 0.0413 - val_sparse_categorical_accuracy: 0.9904 - val_student_loss: 0.8547 - 263ms/epoch - 18ms/step
# Epoch 29/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9033 - student_loss: 0.8961 - distillation_loss: 0.0382 - val_sparse_categorical_accuracy: 0.9904 - val_student_loss: 0.8553 - 289ms/epoch - 19ms/step
# Epoch 30/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9110 - student_loss: 0.8657 - distillation_loss: 0.0350 - val_sparse_categorical_accuracy: 0.9904 - val_student_loss: 0.8587 - 268ms/epoch - 18ms/step
# Epoch 31/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9121 - student_loss: 0.8752 - distillation_loss: 0.0483 - val_sparse_categorical_accuracy: 0.9880 - val_student_loss: 0.8774 - 270ms/epoch - 18ms/step
# Epoch 32/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.8967 - student_loss: 0.9067 - distillation_loss: 0.0267 - val_sparse_categorical_accuracy: 0.9904 - val_student_loss: 0.8685 - 281ms/epoch - 19ms/step
# Epoch 33/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9220 - student_loss: 0.7973 - distillation_loss: 0.0322 - val_sparse_categorical_accuracy: 0.9880 - val_student_loss: 0.8741 - 282ms/epoch - 19ms/step
# Epoch 34/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9121 - student_loss: 0.9483 - distillation_loss: 0.0280 - val_sparse_categorical_accuracy: 0.9880 - val_student_loss: 0.8664 - 264ms/epoch - 18ms/step
# Epoch 35/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9033 - student_loss: 0.8651 - distillation_loss: 0.0430 - val_sparse_categorical_accuracy: 0.9880 - val_student_loss: 0.8480 - 272ms/epoch - 18ms/step
# Epoch 36/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9033 - student_loss: 1.0553 - distillation_loss: 0.0550 - val_sparse_categorical_accuracy: 0.9880 - val_student_loss: 0.8570 - 280ms/epoch - 19ms/step
# Epoch 37/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9022 - student_loss: 0.8506 - distillation_loss: 0.0318 - val_sparse_categorical_accuracy: 0.9832 - val_student_loss: 0.8730 - 266ms/epoch - 18ms/step
# Epoch 38/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9231 - student_loss: 0.9305 - distillation_loss: 0.0516 - val_sparse_categorical_accuracy: 0.9856 - val_student_loss: 0.8780 - 269ms/epoch - 18ms/step
# Epoch 39/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9264 - student_loss: 0.7895 - distillation_loss: 0.0247 - val_sparse_categorical_accuracy: 0.9856 - val_student_loss: 0.8495 - 272ms/epoch - 18ms/step
# Epoch 40/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9165 - student_loss: 0.8898 - distillation_loss: 0.0498 - val_sparse_categorical_accuracy: 0.9880 - val_student_loss: 0.8187 - 284ms/epoch - 19ms/step
# Epoch 41/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9154 - student_loss: 0.8688 - distillation_loss: 0.0265 - val_sparse_categorical_accuracy: 0.9880 - val_student_loss: 0.8157 - 277ms/epoch - 18ms/step
# Epoch 42/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9066 - student_loss: 0.8237 - distillation_loss: 0.0324 - val_sparse_categorical_accuracy: 0.9880 - val_student_loss: 0.8160 - 271ms/epoch - 18ms/step
# Epoch 43/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9121 - student_loss: 0.7898 - distillation_loss: 0.0353 - val_sparse_categorical_accuracy: 0.9880 - val_student_loss: 0.8443 - 292ms/epoch - 19ms/step
# Epoch 44/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9209 - student_loss: 0.8614 - distillation_loss: 0.0334 - val_sparse_categorical_accuracy: 0.9904 - val_student_loss: 0.8151 - 272ms/epoch - 18ms/step
# Epoch 45/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9231 - student_loss: 0.8203 - distillation_loss: 0.0382 - val_sparse_categorical_accuracy: 0.9904 - val_student_loss: 0.8343 - 274ms/epoch - 18ms/step
# Epoch 46/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9187 - student_loss: 0.8901 - distillation_loss: 0.0320 - val_sparse_categorical_accuracy: 0.9904 - val_student_loss: 0.8318 - 269ms/epoch - 18ms/step
# Epoch 47/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9385 - student_loss: 0.8393 - distillation_loss: 0.0335 - val_sparse_categorical_accuracy: 0.9880 - val_student_loss: 0.8429 - 276ms/epoch - 18ms/step
# Epoch 48/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9154 - student_loss: 0.8091 - distillation_loss: 0.0289 - val_sparse_categorical_accuracy: 0.9832 - val_student_loss: 0.8706 - 274ms/epoch - 18ms/step
# Epoch 49/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9242 - student_loss: 0.8529 - distillation_loss: 0.0380 - val_sparse_categorical_accuracy: 0.9880 - val_student_loss: 0.8809 - 286ms/epoch - 19ms/step
# Epoch 50/50
# 15/15 - 0s - sparse_categorical_accuracy: 0.9154 - student_loss: 0.9098 - distillation_loss: 0.0223 - val_sparse_categorical_accuracy: 0.9904 - val_student_loss: 0.8601 - 286ms/epoch - 19ms/step
# 7/7 - 0s - sparse_categorical_accuracy: 0.9904 - student_loss: 0.8601 - 62ms/epoch - 9ms/step

# %%
#Train student as does usually
student_scratch.compile(loss=tensorflow.keras.losses.sparse_categorical_crossentropy,
              optimizer=tensorflow.keras.optimizers.Adam(),
              metrics=[keras.metrics.SparseCategoricalAccuracy()])

#checkpoint dan save weight untuk student scratch
filepath="weights.student_scratch.hdf5"
checkpoint_student_scratch = ModelCheckpoint(filepath, monitor='val_sparse_categorical_accuracy', verbose=1, save_best_only=True, mode='max')
es_student_s = EarlyStopping(monitor='val_sparse_categorical_accuracy', patience=20)
callbacks_student_scratch_list = [checkpoint_student_scratch, es_student_s]

#Fit the model
student_scratch.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=50, batch_size=64, callbacks=callbacks_student_scratch_list, verbose=2)
# Out:
# Epoch 1/50
#
# Epoch 1: val_sparse_categorical_accuracy improved from -inf to 0.12740, saving model to weights.student_scratch.hdf5
# 15/15 - 4s - loss: 7.2892 - sparse_categorical_accuracy: 0.1912 - val_loss: 3.4272 - val_sparse_categorical_accuracy: 0.1274 - 4s/epoch - 251ms/step
# Epoch 2/50
#
# Epoch 2: val_sparse_categorical_accuracy improved from 0.12740 to 0.23798, saving model to weights.student_scratch.hdf5
# 15/15 - 0s - loss: 5.7167 - sparse_categorical_accuracy: 0.2396 - val_loss: 1.7477 - val_sparse_categorical_accuracy: 0.2380 - 244ms/epoch - 16ms/step
# Epoch 3/50
#
# Epoch 3: val_sparse_categorical_accuracy improved from 0.23798 to 0.47596, saving model to weights.student_scratch.hdf5
# 15/15 - 0s - loss: 3.6868 - sparse_categorical_accuracy: 0.3297 - val_loss: 1.4157 - val_sparse_categorical_accuracy: 0.4760 - 232ms/epoch - 15ms/step
# Epoch 4/50
#
# Epoch 4: val_sparse_categorical_accuracy improved from 0.47596 to 0.56490, saving model to weights.student_scratch.hdf5
# 15/15 - 0s - loss: 2.9761 - sparse_categorical_accuracy: 0.3681 - val_loss: 1.4079 - val_sparse_categorical_accuracy: 0.5649 - 239ms/epoch - 16ms/step
# Epoch 5/50
#
# Epoch 5: val_sparse_categorical_accuracy did not improve from 0.56490
# 15/15 - 0s - loss: 2.4219 - sparse_categorical_accuracy: 0.3692 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.5144 - 196ms/epoch - 13ms/step
# Epoch 6/50
#
# Epoch 6: val_sparse_categorical_accuracy did not improve from 0.56490
# 15/15 - 0s - loss: 2.3820 - sparse_categorical_accuracy: 0.3527 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.4832 - 202ms/epoch - 13ms/step
# Epoch 7/50
#
# Epoch 7: val_sparse_categorical_accuracy did not improve from 0.56490
# 15/15 - 0s - loss: 2.1174 - sparse_categorical_accuracy: 0.3143 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.3942 - 192ms/epoch - 13ms/step
# Epoch 8/50
#
# Epoch 8: val_sparse_categorical_accuracy did not improve from 0.56490
# 15/15 - 0s - loss: 2.2221 - sparse_categorical_accuracy: 0.3286 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.4183 - 206ms/epoch - 14ms/step
# Epoch 9/50
#
# Epoch 9: val_sparse_categorical_accuracy did not improve from 0.56490
# 15/15 - 0s - loss: 1.8592 - sparse_categorical_accuracy: 0.3440 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.4639 - 212ms/epoch - 14ms/step
# Epoch 10/50
#
# Epoch 10: val_sparse_categorical_accuracy did not improve from 0.56490
# 15/15 - 0s - loss: 2.0880 - sparse_categorical_accuracy: 0.3396 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.4543 - 202ms/epoch - 13ms/step
# Epoch 11/50
#
# Epoch 11: val_sparse_categorical_accuracy did not improve from 0.56490
# 15/15 - 0s - loss: 1.7858 - sparse_categorical_accuracy: 0.3571 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.4543 - 194ms/epoch - 13ms/step
# Epoch 12/50
#
# Epoch 12: val_sparse_categorical_accuracy did not improve from 0.56490
# 15/15 - 0s - loss: 1.6136 - sparse_categorical_accuracy: 0.3593 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.4688 - 198ms/epoch - 13ms/step
# Epoch 13/50
#
# Epoch 13: val_sparse_categorical_accuracy did not improve from 0.56490
# 15/15 - 0s - loss: 1.7527 - sparse_categorical_accuracy: 0.3626 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.5120 - 205ms/epoch - 14ms/step
# Epoch 14/50
#
# Epoch 14: val_sparse_categorical_accuracy did not improve from 0.56490
# 15/15 - 0s - loss: 1.6229 - sparse_categorical_accuracy: 0.3593 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.4784 - 205ms/epoch - 14ms/step
# Epoch 15/50
#
# Epoch 15: val_sparse_categorical_accuracy did not improve from 0.56490
# 15/15 - 0s - loss: 1.6038 - sparse_categorical_accuracy: 0.3835 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.4736 - 204ms/epoch - 14ms/step
# Epoch 16/50
#
# Epoch 16: val_sparse_categorical_accuracy did not improve from 0.56490
# 15/15 - 0s - loss: 1.6684 - sparse_categorical_accuracy: 0.3725 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.4327 - 196ms/epoch - 13ms/step
# Epoch 17/50
#
# Epoch 17: val_sparse_categorical_accuracy did not improve from 0.56490
# 15/15 - 0s - loss: 1.6361 - sparse_categorical_accuracy: 0.3418 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.4351 - 201ms/epoch - 13ms/step
# Epoch 18/50
#
# Epoch 18: val_sparse_categorical_accuracy did not improve from 0.56490
# 15/15 - 0s - loss: 1.5442 - sparse_categorical_accuracy: 0.3516 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.4399 - 201ms/epoch - 13ms/step
# Epoch 19/50
#
# Epoch 19: val_sparse_categorical_accuracy did not improve from 0.56490
# 15/15 - 0s - loss: 1.6437 - sparse_categorical_accuracy: 0.3462 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.4207 - 212ms/epoch - 14ms/step
# Epoch 20/50
#
# Epoch 20: val_sparse_categorical_accuracy did not improve from 0.56490
# 15/15 - 0s - loss: 1.4825 - sparse_categorical_accuracy: 0.3440 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.4207 - 196ms/epoch - 13ms/step
# Epoch 21/50
#
# Epoch 21: val_sparse_categorical_accuracy did not improve from 0.56490
# 15/15 - 0s - loss: 1.5746 - sparse_categorical_accuracy: 0.3648 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.4375 - 196ms/epoch - 13ms/step
# Epoch 22/50
#
# Epoch 22: val_sparse_categorical_accuracy did not improve from 0.56490
# 15/15 - 0s - loss: 1.5411 - sparse_categorical_accuracy: 0.3637 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.4543 - 208ms/epoch - 14ms/step
# Epoch 23/50
#
# Epoch 23: val_sparse_categorical_accuracy did not improve from 0.56490
# 15/15 - 0s - loss: 1.5037 - sparse_categorical_accuracy: 0.3626 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.4495 - 214ms/epoch - 14ms/step
# Epoch 24/50
#
# Epoch 24: val_sparse_categorical_accuracy did not improve from 0.56490
# 15/15 - 0s - loss: 1.4860 - sparse_categorical_accuracy: 0.3407 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.4688 - 203ms/epoch - 14ms/step

# %%
Play an audio beep. Any audio URL will do.
from google.colab import output
output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')
